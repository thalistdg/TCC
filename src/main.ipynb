# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from fitter import Fitter
from scipy.stats import exponnorm, erlang, gennorm

# %%
def load_data(column):
    stream = []
    days = range(1, 23) # 1, 32
    months = range(1, 2) #1, 3
    for month in months:
        month_2_digits = '{month:02}'.format(month=month)
        path = './COVID19_Tweets_Dataset_2020/Summary_Sentiment/2020_' + month_2_digits + '/'

        for day in days:
            if month == 2 and day > 29:
                continue
            if month == 1 and day < 22:
                continue

            for hour in range(5): # 24
                file_name = path + f'2020_{month_2_digits}_' + '{day:02}'.format(day=day) + '_{hour:02}'.format(hour=hour) + '_Summary_Sentiment.csv'
                stream.append(pd.read_csv(file_name)[column])

    return pd.concat(stream, ignore_index=True), stream

# %%
stream_ln, tweets_per_file = load_data('Logits_Negative')

# %%
def get_fitted_ks_values(data):
    f = Fitter(data)
    f.fit()
    return f.summary(plot=False, clf=False)['ks_pvalue'].values

# %%
ks_values = []
for tweets_hour in tweets_per_file:
    ks_values.append(get_fitted_ks_values(tweets_hour))

np.mean([i>=.01 for i in np.concatenate(ks_values)])
# Out:
# Fitting 110 distributions:   0%|          | 0/110 [00:00<?, ?it/s]SKIPPED _fit distribution (taking more than 30 seconds)
# Fitting 110 distributions:  44%|████▎     | 48/110 [00:05<00:09,  6.68it/s]SKIPPED kstwo distribution (taking more than 30 seconds)
# Fitting 110 distributions:  55%|█████▍    | 60/110 [00:08<00:17,  2.86it/s]SKIPPED loguniform distribution (taking more than 30 seconds)
# Fitting 110 distributions:  72%|███████▏  | 79/110 [00:14<00:16,  1.85it/s]SKIPPED reciprocal distribution (taking more than 30 seconds)
# Fitting 110 distributions:  73%|███████▎  | 80/110 [00:15<00:14,  2.01it/s]SKIPPED rv_histogram distribution (taking more than 30 seconds)
# SKIPPED rv_continuous distribution (taking more than 30 seconds)
# Fitting 110 distributions:  95%|█████████▌| 105/110 [00:29<00:02,  2.14it/s]SKIPPED levy_stable distribution (taking more than 30 seconds)
# Fitting 110 distributions:  97%|█████████▋| 107/110 [00:36<00:05,  1.98s/it]SKIPPED studentized_range distribution (taking more than 30 seconds)
# Fitting 110 distributions:  98%|█████████▊| 108/110 [00:46<00:07,  3.74s/it]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED vonmises distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [00:57<00:00,  1.90it/s]
# Fitting 110 distributions:   0%|          | 0/110 [00:00<?, ?it/s]SKIPPED _fit distribution (taking more than 30 seconds)
# Fitting 110 distributions:  28%|██▊       | 31/110 [00:09<00:28,  2.73it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
# Fitting 110 distributions:  39%|███▉      | 43/110 [00:10<00:08,  7.88it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# Fitting 110 distributions:  45%|████▍     | 49/110 [00:11<00:10,  6.06it/s]SKIPPED kstwo distribution (taking more than 30 seconds)
# Fitting 110 distributions:  55%|█████▌    | 61/110 [00:13<00:08,  5.61it/s]SKIPPED loguniform distribution (taking more than 30 seconds)
# Fitting 110 distributions:  72%|███████▏  | 79/110 [00:20<00:11,  2.78it/s]SKIPPED reciprocal distribution (taking more than 30 seconds)
# Fitting 110 distributions:  74%|███████▎  | 81/110 [00:21<00:10,  2.80it/s]SKIPPED rv_continuous distribution (taking more than 30 seconds)
# Fitting 110 distributions:  75%|███████▍  | 82/110 [00:21<00:09,  2.82it/s]SKIPPED rv_histogram distribution (taking more than 30 seconds)
# Fitting 110 distributions:  95%|█████████▌| 105/110 [00:39<00:04,  1.02it/s]SKIPPED kappa4 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  96%|█████████▋| 106/110 [00:41<00:05,  1.26s/it]SKIPPED levy_stable distribution (taking more than 30 seconds)
# Fitting 110 distributions:  97%|█████████▋| 107/110 [00:42<00:04,  1.34s/it]SKIPPED studentized_range distribution (taking more than 30 seconds)
# Fitting 110 distributions:  98%|█████████▊| 108/110 [00:54<00:08,  4.37s/it]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# Fitting 110 distributions:  99%|█████████▉| 109/110 [01:01<00:05,  5.19s/it]SKIPPED vonmises distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [01:01<00:00,  1.78it/s]
# Fitting 110 distributions:   0%|          | 0/110 [00:00<?, ?it/s]SKIPPED _fit distribution (taking more than 30 seconds)
# Fitting 110 distributions:  28%|██▊       | 31/110 [00:07<00:28,  2.79it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
# Fitting 110 distributions:  29%|██▉       | 32/110 [00:07<00:22,  3.44it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
# Fitting 110 distributions:  45%|████▌     | 50/110 [00:10<00:09,  6.61it/s]SKIPPED kstwo distribution (taking more than 30 seconds)
# Fitting 110 distributions:  57%|█████▋    | 63/110 [00:13<00:08,  5.23it/s]SKIPPED loguniform distribution (taking more than 30 seconds)
# Fitting 110 distributions:  73%|███████▎  | 80/110 [00:17<00:09,  3.00it/s]SKIPPED reciprocal distribution (taking more than 30 seconds)
# Fitting 110 distributions:  74%|███████▎  | 81/110 [00:17<00:09,  2.94it/s]SKIPPED rv_continuous distribution (taking more than 30 seconds)
# Fitting 110 distributions:  75%|███████▍  | 82/110 [00:18<00:08,  3.49it/s]SKIPPED rv_histogram distribution (taking more than 30 seconds)
# Fitting 110 distributions:  92%|█████████▏| 101/110 [00:31<00:04,  1.91it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# Fitting 110 distributions:  97%|█████████▋| 107/110 [00:37<00:04,  1.39s/it]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# Fitting 110 distributions:  98%|█████████▊| 108/110 [00:48<00:08,  4.35s/it]SKIPPED studentized_range distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [00:52<00:00,  2.09it/s]
# Fitting 110 distributions:   0%|          | 0/110 [00:00<?, ?it/s]SKIPPED _fit distribution (taking more than 30 seconds)
# Fitting 110 distributions:  45%|████▍     | 49/110 [00:13<00:12,  4.72it/s]SKIPPED kstwo distribution (taking more than 30 seconds)
# Fitting 110 distributions:  56%|█████▋    | 62/110 [00:16<00:15,  3.05it/s]SKIPPED loguniform distribution (taking more than 30 seconds)
# Fitting 110 distributions:  72%|███████▏  | 79/110 [00:21<00:09,  3.26it/s]SKIPPED reciprocal distribution (taking more than 30 seconds)
# Fitting 110 distributions:  74%|███████▎  | 81/110 [00:22<00:13,  2.10it/s]SKIPPED rv_histogram distribution (taking more than 30 seconds)
# Fitting 110 distributions:  75%|███████▌  | 83/110 [00:22<00:08,  3.06it/s]SKIPPED rv_continuous distribution (taking more than 30 seconds)
# Fitting 110 distributions:  81%|████████  | 89/110 [00:25<00:12,  1.62it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# Fitting 110 distributions:  95%|█████████▍| 104/110 [00:42<00:04,  1.44it/s]SKIPPED kappa4 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  95%|█████████▌| 105/110 [00:43<00:03,  1.54it/s]SKIPPED levy_stable distribution (taking more than 30 seconds)
# Fitting 110 distributions:  97%|█████████▋| 107/110 [00:46<00:03,  1.29s/it]SKIPPED studentized_range distribution (taking more than 30 seconds)
# Fitting 110 distributions:  98%|█████████▊| 108/110 [00:53<00:05,  2.99s/it]SKIPPED vonmises distribution (taking more than 30 seconds)
# Fitting 110 distributions:  99%|█████████▉| 109/110 [01:06<00:06,  6.12s/it]SKIPPED vonmises_line distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [01:07<00:00,  1.62it/s]
# Fitting 110 distributions:   0%|          | 0/110 [00:00<?, ?it/s]SKIPPED _fit distribution (taking more than 30 seconds)
# Fitting 110 distributions:   5%|▍         | 5/110 [00:02<00:43,  2.42it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# Fitting 110 distributions:  38%|███▊      | 42/110 [00:16<00:22,  3.07it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
# Fitting 110 distributions:  45%|████▍     | 49/110 [00:19<00:29,  2.08it/s]SKIPPED kstwo distribution (taking more than 30 seconds)
# Fitting 110 distributions:  61%|██████    | 67/110 [00:25<00:13,  3.19it/s]SKIPPED loguniform distribution (taking more than 30 seconds)
# Fitting 110 distributions:  72%|███████▏  | 79/110 [00:33<00:26,  1.19it/s]SKIPPED reciprocal distribution (taking more than 30 seconds)
# Fitting 110 distributions:  73%|███████▎  | 80/110 [00:34<00:27,  1.10it/s]SKIPPED rv_continuous distribution (taking more than 30 seconds)
# Fitting 110 distributions:  74%|███████▎  | 81/110 [00:35<00:22,  1.31it/s]SKIPPED rv_histogram distribution (taking more than 30 seconds)
# Fitting 110 distributions:  85%|████████▌ | 94/110 [00:48<00:19,  1.21s/it]SKIPPED kappa4 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  91%|█████████ | 100/110 [00:49<00:04,  2.43it/s]SKIPPED levy_stable distribution (taking more than 30 seconds)
# Fitting 110 distributions:  97%|█████████▋| 107/110 [00:56<00:02,  1.18it/s]SKIPPED studentized_range distribution (taking more than 30 seconds)
# Fitting 110 distributions:  98%|█████████▊| 108/110 [01:06<00:07,  3.56s/it]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED vonmises distribution (taking more than 30 seconds)
# Fitting 110 distributions:  99%|█████████▉| 109/110 [01:19<00:06,  6.39s/it]SKIPPED vonmises_line distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [01:19<00:00,  1.38it/s]
# 0.92

# %%
np.mean([i>=.01 for i in get_fitted_ks_values(stream_ln)])
# Out:
# Fitting 110 distributions:   0%|          | 0/110 [00:00<?, ?it/s]SKIPPED _fit distribution (taking more than 30 seconds)
# Fitting 110 distributions:   2%|▏         | 2/110 [00:13<14:01,  7.79s/it]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED arcsine distribution (taking more than 30 seconds)
# Fitting 110 distributions:   3%|▎         | 3/110 [00:31<22:11, 12.44s/it]SKIPPED alpha distribution (taking more than 30 seconds)
# SKIPPED bradford distribution (taking more than 30 seconds)
# SKIPPED beta distribution (taking more than 30 seconds)
# Fitting 110 distributions:   4%|▎         | 4/110 [00:32<13:33,  7.67s/it]SKIPPED argus distribution (taking more than 30 seconds)
# Fitting 110 distributions:   6%|▋         | 7/110 [00:32<05:03,  2.95s/it]SKIPPED betaprime distribution (taking more than 30 seconds)
# SKIPPED burr distribution (taking more than 30 seconds)
# Fitting 110 distributions:  12%|█▏        | 13/110 [00:43<03:21,  2.07s/it]SKIPPED burr12 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  16%|█▋        | 18/110 [00:59<05:28,  3.58s/it]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED chi2 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  17%|█▋        | 19/110 [01:02<05:09,  3.40s/it]SKIPPED crystalball distribution (taking more than 30 seconds)
# Fitting 110 distributions:  18%|█▊        | 20/110 [01:02<03:48,  2.54s/it]SKIPPED exponpow distribution (taking more than 30 seconds)
# Fitting 110 distributions:  19%|█▉        | 21/110 [01:13<07:32,  5.08s/it]SKIPPED exponweib distribution (taking more than 30 seconds)
# Fitting 110 distributions:  20%|██        | 22/110 [01:14<05:22,  3.66s/it]SKIPPED f distribution (taking more than 30 seconds)
# Fitting 110 distributions:  22%|██▏       | 24/110 [01:15<03:04,  2.15s/it]SKIPPED fatiguelife distribution (taking more than 30 seconds)
# Fitting 110 distributions:  23%|██▎       | 25/110 [01:21<04:28,  3.15s/it]SKIPPED fisk distribution (taking more than 30 seconds)
# Fitting 110 distributions:  24%|██▎       | 26/110 [01:23<04:00,  2.87s/it]SKIPPED foldcauchy distribution (taking more than 30 seconds)
# Fitting 110 distributions:  25%|██▍       | 27/110 [01:29<05:19,  3.86s/it]SKIPPED foldnorm distribution (taking more than 30 seconds)
# Fitting 110 distributions:  25%|██▌       | 28/110 [01:32<04:49,  3.53s/it]SKIPPED gausshyper distribution (taking more than 30 seconds)
# Fitting 110 distributions:  26%|██▋       | 29/110 [01:44<08:04,  5.98s/it]SKIPPED genexpon distribution (taking more than 30 seconds)
# Fitting 110 distributions:  27%|██▋       | 30/110 [01:44<05:42,  4.29s/it]SKIPPED genextreme distribution (taking more than 30 seconds)
# Fitting 110 distributions:  28%|██▊       | 31/110 [01:45<04:30,  3.42s/it]SKIPPED gengamma distribution (taking more than 30 seconds)
# Fitting 110 distributions:  29%|██▉       | 32/110 [01:46<03:22,  2.59s/it]SKIPPED genhalflogistic distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
# Fitting 110 distributions:  35%|███▍      | 38/110 [01:56<01:49,  1.51s/it]SKIPPED geninvgauss distribution (taking more than 30 seconds)
# Fitting 110 distributions:  39%|███▉      | 43/110 [02:14<02:49,  2.54s/it]SKIPPED genpareto distribution (taking more than 30 seconds)
# Fitting 110 distributions:  43%|████▎     | 47/110 [02:15<00:56,  1.11it/s]SKIPPED halfgennorm distribution (taking more than 30 seconds)
# Fitting 110 distributions:  44%|████▎     | 48/110 [02:24<03:07,  3.02s/it]SKIPPED invgamma distribution (taking more than 30 seconds)
# Fitting 110 distributions:  45%|████▍     | 49/110 [02:40<06:37,  6.51s/it]SKIPPED kstwo distribution (taking more than 30 seconds)
# Fitting 110 distributions:  45%|████▌     | 50/110 [02:40<04:49,  4.82s/it]SKIPPED invgauss distribution (taking more than 30 seconds)
# Fitting 110 distributions:  47%|████▋     | 52/110 [02:43<03:03,  3.16s/it]SKIPPED johnsonsb distribution (taking more than 30 seconds)
# SKIPPED invweibull distribution (taking more than 30 seconds)
# Fitting 110 distributions:  49%|████▉     | 54/110 [02:44<01:39,  1.78s/it]SKIPPED johnsonsu distribution (taking more than 30 seconds)
# SKIPPED kappa3 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  50%|█████     | 55/110 [02:45<01:14,  1.35s/it]SKIPPED kappa4 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  54%|█████▎    | 59/110 [02:52<01:51,  2.19s/it]SKIPPED ksone distribution (taking more than 30 seconds)
# Fitting 110 distributions:  55%|█████▍    | 60/110 [02:54<01:56,  2.33s/it]SKIPPED loguniform distribution (taking more than 30 seconds)
# Fitting 110 distributions:  60%|██████    | 66/110 [03:12<02:57,  4.04s/it]SKIPPED levy_stable distribution (taking more than 30 seconds)
# Fitting 110 distributions:  61%|██████    | 67/110 [03:15<02:51,  3.99s/it]SKIPPED loggamma distribution (taking more than 30 seconds)
# Fitting 110 distributions:  62%|██████▏   | 68/110 [03:16<02:03,  2.95s/it]SKIPPED loglaplace distribution (taking more than 30 seconds)
# Fitting 110 distributions:  65%|██████▌   | 72/110 [03:22<01:18,  2.06s/it]SKIPPED lognorm distribution (taking more than 30 seconds)
# Fitting 110 distributions:  67%|██████▋   | 74/110 [03:25<01:08,  1.90s/it]SKIPPED lomax distribution (taking more than 30 seconds)
# Fitting 110 distributions:  68%|██████▊   | 75/110 [03:26<01:00,  1.72s/it]SKIPPED mielke distribution (taking more than 30 seconds)
# Fitting 110 distributions:  70%|███████   | 77/110 [03:29<00:46,  1.42s/it]SKIPPED ncf distribution (taking more than 30 seconds)
# Fitting 110 distributions:  71%|███████   | 78/110 [03:42<02:37,  4.94s/it]SKIPPED nct distribution (taking more than 30 seconds)
# Fitting 110 distributions:  72%|███████▏  | 79/110 [03:46<02:23,  4.64s/it]SKIPPED ncx2 distribution (taking more than 30 seconds)
# SKIPPED reciprocal distribution (taking more than 30 seconds)
# Fitting 110 distributions:  73%|███████▎  | 80/110 [03:47<01:48,  3.62s/it]SKIPPED norminvgauss distribution (taking more than 30 seconds)
# Fitting 110 distributions:  75%|███████▍  | 82/110 [03:48<00:56,  2.03s/it]SKIPPED rv_continuous distribution (taking more than 30 seconds)
# SKIPPED rv_histogram distribution (taking more than 30 seconds)
# Fitting 110 distributions:  77%|███████▋  | 85/110 [03:50<00:29,  1.19s/it]SKIPPED pearson3 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  78%|███████▊  | 86/110 [03:52<00:33,  1.40s/it]SKIPPED powerlognorm distribution (taking more than 30 seconds)
# Fitting 110 distributions:  79%|███████▉  | 87/110 [03:55<00:46,  2.04s/it]SKIPPED rdist distribution (taking more than 30 seconds)
# Fitting 110 distributions:  81%|████████  | 89/110 [04:07<01:29,  4.26s/it]SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# Fitting 110 distributions:  82%|████████▏ | 90/110 [04:12<01:30,  4.52s/it]SKIPPED rice distribution (taking more than 30 seconds)
# Fitting 110 distributions:  83%|████████▎ | 91/110 [04:17<01:28,  4.65s/it]SKIPPED skewcauchy distribution (taking more than 30 seconds)
# Fitting 110 distributions:  84%|████████▎ | 92/110 [04:19<01:08,  3.78s/it]SKIPPED skewnorm distribution (taking more than 30 seconds)
# Fitting 110 distributions:  85%|████████▍ | 93/110 [04:20<00:50,  2.99s/it]SKIPPED studentized_range distribution (taking more than 30 seconds)
# Fitting 110 distributions:  85%|████████▌ | 94/110 [04:22<00:42,  2.68s/it]SKIPPED t distribution (taking more than 30 seconds)
# Fitting 110 distributions:  86%|████████▋ | 95/110 [04:25<00:43,  2.87s/it]SKIPPED trapezoid distribution (taking more than 30 seconds)
# Fitting 110 distributions:  89%|████████▉ | 98/110 [04:35<00:36,  3.08s/it]SKIPPED trapz distribution (taking more than 30 seconds)
# Fitting 110 distributions:  90%|█████████ | 99/110 [04:38<00:32,  2.98s/it]SKIPPED triang distribution (taking more than 30 seconds)
# Fitting 110 distributions:  91%|█████████ | 100/110 [04:43<00:36,  3.70s/it]SKIPPED truncnorm distribution (taking more than 30 seconds)
# Fitting 110 distributions:  92%|█████████▏| 101/110 [04:49<00:41,  4.56s/it]SKIPPED truncpareto distribution (taking more than 30 seconds)
# Fitting 110 distributions:  93%|█████████▎| 102/110 [04:51<00:28,  3.58s/it]SKIPPED truncweibull_min distribution (taking more than 30 seconds)
# Fitting 110 distributions:  95%|█████████▍| 104/110 [04:53<00:13,  2.22s/it]SKIPPED tukeylambda distribution (taking more than 30 seconds)
# Fitting 110 distributions:  95%|█████████▌| 105/110 [04:56<00:12,  2.40s/it]SKIPPED vonmises distribution (taking more than 30 seconds)
# Fitting 110 distributions:  96%|█████████▋| 106/110 [05:01<00:12,  3.16s/it]SKIPPED vonmises_line distribution (taking more than 30 seconds)
# Fitting 110 distributions:  98%|█████████▊| 108/110 [05:09<00:07,  3.67s/it]SKIPPED weibull_max distribution (taking more than 30 seconds)
# Fitting 110 distributions:  99%|█████████▉| 109/110 [05:13<00:03,  3.83s/it]SKIPPED wrapcauchy distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [05:21<00:00,  2.93s/it]
# 0.0
