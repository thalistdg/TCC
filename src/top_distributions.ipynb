# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import tqdm

from fitter import Fitter
from scipy.stats import exponnorm, erlang, gennorm

# %%
def load_data(column):
    stream = []
    days = range(1, 27) # 1, 32
    months = range(1, 2) #1, 3
    for month in months:
        month_2_digits = '{month:02}'.format(month=month)
        path = '../COVID19_Tweets_Dataset_2020/Summary_Sentiment/2020_' + month_2_digits + '/'

        for day in days:
            if month == 2 and day > 29:
                continue
            if month == 1 and day < 22:
                continue

            for hour in range(24): # 24
                file_name = path + f'2020_{month_2_digits}_' + '{day:02}'.format(day=day) + '_{hour:02}'.format(hour=hour) + '_Summary_Sentiment.csv'
                stream.append(pd.read_csv(file_name)[column])

    return (pd.concat(stream, ignore_index=True), stream) if len(stream) > 0 else (stream, stream)

# %%
stream_ln, tweets_per_file = load_data('Logits_Negative')

# %%
def get_fitted_summary(data):
    f = Fitter(data)
    # f.distributions = f.distributions[:3]
    f.fit()
    return f.summary(method='ks_pvalue', plot=False, clf=False, Nbest=110)

def get_dist_ks_values():
    n_tweets = 0
    dist_ks_values = {}
    n_files = 0
    for tweets_hour in tqdm.tqdm(tweets_per_file):
        n_files += 1
        n_tweets += len(tweets_hour)
        table = get_fitted_summary(tweets_hour)
        for i, row in table.iterrows():
            if i in dist_ks_values:
                dist_ks_values[i].append(row['ks_pvalue'])
            else:
                dist_ks_values[i] = [row['ks_pvalue']]

        if n_files % 24 == 0:
            pd.DataFrame(dist_ks_values).to_pickle('../results/top_distributions_day_{}.pkl'.format(n_files//24))
            dist_ks_values = {}

    if len(dist_ks_values) > 0:
        pd.DataFrame(dist_ks_values).to_pickle('../results/top_distributions_day_{}.pkl'.format(n_files/24))

    print(f'Processed {len(tweets_per_file)} files!')
    print(f'Processed {len(tweets_per_file)//24} days!')
    print(f'Processed {n_tweets} tweets!')

    # return pd.DataFrame(dist_ks_values)

# %%
get_dist_ks_values()
# Out:
#   0%|          | 0/120 [00:00<?, ?it/s]SKIPPED _fit distribution (taking more than 30 seconds)
#
# SKIPPED kstwo distribution (taking more than 30 seconds)SKIPPED loguniform distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  73%|███████▎  | 80/110 [00:14<00:13,  2.27it/s]SKIPPED reciprocal distribution (taking more than 30 seconds)
# SKIPPED rv_continuous distribution (taking more than 30 seconds)
# Fitting 110 distributions:  74%|███████▎  | 81/110 [00:14<00:10,  2.64it/s]SKIPPED rv_histogram distribution (taking more than 30 seconds)SKIPPED levy_stable distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
#
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,SKIPPED vonmises distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [00:52<00:00,  2.09it/s]
#   1%|          | 1/120 [00:52<1:44:51, 52.87s/it]SKIPPED _fit distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
#
# Fitting 110 distributions:  41%|████      | 45/110 [00:16<00:11,  5.83it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED kstwo distribution (taking more than 30 seconds)SKIPPED loguniform distribution (taking more than 30 seconds)
#
# SKIPPED reciprocal distribution (taking more than 30 seconds)SKIPPED rv_continuous distribution (taking more than 30 seconds)
# SKIPPED rv_histogram distribution (taking more than 30 seconds)
# SKIPPED kappa4 distribution (taking more than 30 seconds)
# SKIPPED levy_stable distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED vonmises distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [01:11<00:00,  1.55it/s]
#   2%|▏         | 2/120 [02:05<2:06:22, 64.26s/it]SKIPPED _fit distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
#
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
# SKIPPED kstwo distribution (taking more than 30 seconds)SKIPPED loguniform distribution (taking more than 30 seconds)
#
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED rv_continuous distribution (taking more than 30 seconds)
# Fitting 110 distributions:  67%|██████▋   | 74/110 [00:19<00:12,  2.87it/s]SKIPPED reciprocal distribution (taking more than 30 seconds)
# SKIPPED rv_histogram distribution (taking more than 30 seconds)/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [00:55<00:00,  1.96it/s]
#   2%|▎         | 3/120 [03:01<1:58:18, 60.67s/it]SKIPPED _fit distribution (taking more than 30 seconds)
#
# SKIPPED kstwo distribution (taking more than 30 seconds)SKIPPED loguniform distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  57%|█████▋    | 63/110 [00:22<00:21,  2.18it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED reciprocal distribution (taking more than 30 seconds)SKIPPED rv_continuous distribution (taking more than 30 seconds)
# SKIPPED rv_histogram distribution (taking more than 30 seconds)
#
# SKIPPED kappa4 distribution (taking more than 30 seconds)
# SKIPPED levy_stable distribution (taking more than 30 seconds)SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
#
# Fitting 110 distributions: 100%|██████████| 110/110 [01:14<00:00,  1.49it/s]
#   3%|▎         | 4/120 [04:16<2:07:52, 66.14s/it]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED _fit distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  30%|███       | 33/110 [00:18<01:05,  1.17it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
#
# SKIPPED kstwo distribution (taking more than 30 seconds)
# Fitting 110 distributions:  52%|█████▏    | 57/110 [00:30<00:32,  1.63it/s]SKIPPED loguniform distribution (taking more than 30 seconds)SKIPPED reciprocal distribution (taking more than 30 seconds)
# SKIPPED rv_continuous distribution (taking more than 30 seconds)
#
# SKIPPED rv_histogram distribution (taking more than 30 seconds)SKIPPED kappa4 distribution (taking more than 30 seconds)
# SKIPPED levy_stable distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
# SKIPPED vonmises_line distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [01:28<00:00,  1.24it/s]
#   4%|▍         | 5/120 [05:46<2:23:17, 74.76s/it]SKIPPED _fit distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#
# Fitting 110 distributions:  30%|███       | 33/110 [00:22<00:45,  1.68it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
# Fitting 110 distributions:  38%|███▊      | 42/110 [00:28<00:40,  1.69it/s]SKIPPED kstwo distribution (taking more than 30 seconds)
#
# SKIPPED loguniform distribution (taking more than 30 seconds)SKIPPED rv_continuous distribution (taking more than 30 seconds)
#
# SKIPPED rv_histogram distribution (taking more than 30 seconds)
# SKIPPED reciprocal distribution (taking more than 30 seconds)
# SKIPPED kappa4 distribution (taking more than 30 seconds)SKIPPED levy_stable distribution (taking more than 30 seconds)
# SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED vonmises distribution (taking more than 30 seconds)
#
# Fitting 110 distributions: 100%|██████████| 110/110 [01:35<00:00,  1.15it/s]
#   5%|▌         | 6/120 [07:23<2:36:26, 82.34s/it]SKIPPED _fit distribution (taking more than 30 seconds)
#
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# Fitting 110 distributions:  38%|███▊      | 42/110 [00:32<00:50,  1.34it/s]SKIPPED kstwo distribution (taking more than 30 seconds)SKIPPED loguniform distribution (taking more than 30 seconds)
#
# SKIPPED reciprocal distribution (taking more than 30 seconds)
# Fitting 110 distributions:  69%|██████▉   | 76/110 [00:55<00:20,  1.62it/s]SKIPPED rv_continuous distribution (taking more than 30 seconds)
#
# SKIPPED rv_histogram distribution (taking more than 30 seconds)
# SKIPPED kappa4 distribution (taking more than 30 seconds)SKIPPED levy_stable distribution (taking more than 30 seconds)
#
# SKIPPED ncx2 distribution (taking more than 30 seconds)SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
# SKIPPED vonmises_line distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# Fitting 110 distributions: 100%|██████████| 110/110 [01:45<00:00,  1.04it/s]
#   6%|▌         | 7/120 [09:10<2:50:28, 90.52s/it]SKIPPED _fit distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#
# SKIPPED kstwo distribution (taking more than 30 seconds)SKIPPED loguniform distribution (taking more than 30 seconds)
#
# SKIPPED kappa4 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  73%|███████▎  | 80/110 [01:37<01:18,  2.62s/it]SKIPPED reciprocal distribution (taking more than 30 seconds)
# SKIPPED rv_histogram distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  74%|███████▎  | 81/110 [01:38<01:02,  2.15s/it]SKIPPED rv_continuous distribution (taking more than 30 seconds)
# SKIPPED ncx2 distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
# SKIPPED vonmises_line distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [02:30<00:00,  1.37s/it]
#   7%|▋         | 8/120 [11:42<3:25:13, 109.94s/it]SKIPPED _fit distribution (taking more than 30 seconds)
# SKIPPED burr distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  31%|███       | 34/110 [00:32<00:47,  1.59it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
#
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# Fitting 110 distributions:  38%|███▊      | 42/110 [00:40<00:58,  1.16it/s]SKIPPED kstwo distribution (taking more than 30 seconds)SKIPPED loguniform distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  67%|██████▋   | 74/110 [01:05<00:24,  1.49it/s]SKIPPED reciprocal distribution (taking more than 30 seconds)
#
# SKIPPED rv_continuous distribution (taking more than 30 seconds)SKIPPED rv_histogram distribution (taking more than 30 seconds)
# SKIPPED kappa4 distribution (taking more than 30 seconds)
# SKIPPED levy_stable distribution (taking more than 30 seconds)
# SKIPPED ncx2 distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  95%|█████████▌| 105/110 [01:32<00:03,  1.27it/s]SKIPPED recipinvgauss distribution (taking more than 30 seconds)SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
# SKIPPED vonmises_line distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [01:58<00:00,  1.08s/it]
#   8%|▊         | 9/120 [13:42<3:29:17, 113.13s/it]SKIPPED _fit distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED argus distribution (taking more than 30 seconds)
#
# SKIPPED betaprime distribution (taking more than 30 seconds)
# SKIPPED arcsine distribution (taking more than 30 seconds)
# SKIPPED bradford distribution (taking more than 30 seconds)SKIPPED burr distribution (taking more than 30 seconds)
# SKIPPED alpha distribution (taking more than 30 seconds)
#
# SKIPPED beta distribution (taking more than 30 seconds)
# Fitting 110 distributions:   4%|▎         | 4/110 [00:33<13:33,  7.67s/it]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,SKIPPED burr12 distribution (taking more than 30 seconds)
# SKIPPED chi distribution (taking more than 30 seconds)
#
# SKIPPED chi2 distribution (taking more than 30 seconds)SKIPPED crystalball distribution (taking more than 30 seconds)
#
# SKIPPED dweibull distribution (taking more than 30 seconds)SKIPPED dgamma distribution (taking more than 30 seconds)
# SKIPPED erlang distribution (taking more than 30 seconds)
# SKIPPED exponpow distribution (taking more than 30 seconds)
# SKIPPED exponweib distribution (taking more than 30 seconds)
# SKIPPED f distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  21%|██        | 23/110 [01:32<07:52,  5.43s/it]SKIPPED fatiguelife distribution (taking more than 30 seconds)SKIPPED fisk distribution (taking more than 30 seconds)
# SKIPPED foldcauchy distribution (taking more than 30 seconds)
# SKIPPED foldnorm distribution (taking more than 30 seconds)
# SKIPPED gamma distribution (taking more than 30 seconds)
# SKIPPED gausshyper distribution (taking more than 30 seconds)
# SKIPPED genexpon distribution (taking more than 30 seconds)
# SKIPPED genextreme distribution (taking more than 30 seconds)
# SKIPPED gengamma distribution (taking more than 30 seconds)
#
# SKIPPED genhalflogistic distribution (taking more than 30 seconds)
# Fitting 110 distributions:  29%|██▉       | 32/110 [02:04<05:23,  4.15s/it]SKIPPED genhyperbolic distribution (taking more than 30 seconds)
# Fitting 110 distributions:  30%|███       | 33/110 [02:04<04:10,  3.25s/it]SKIPPED geninvgauss distribution (taking more than 30 seconds)SKIPPED genlogistic distribution (taking more than 30 seconds)
# SKIPPED gennorm distribution (taking more than 30 seconds)
#
# SKIPPED genpareto distribution (taking more than 30 seconds)SKIPPED gibrat distribution (taking more than 30 seconds)
# SKIPPED gilbrat distribution (taking more than 30 seconds)
# SKIPPED gompertz distribution (taking more than 30 seconds)
# SKIPPED halfgennorm distribution (taking more than 30 seconds)
# SKIPPED halflogistic distribution (taking more than 30 seconds)
# SKIPPED invgamma distribution (taking more than 30 seconds)
# SKIPPED kstwo distribution (taking more than 30 seconds)
# SKIPPED invgauss distribution (taking more than 30 seconds)
# SKIPPED invweibull distribution (taking more than 30 seconds)
# SKIPPED johnsonsb distribution (taking more than 30 seconds)
# SKIPPED johnsonsu distribution (taking more than 30 seconds)
# SKIPPED kappa3 distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  51%|█████     | 56/110 [03:06<01:26,  1.60s/it]SKIPPED kappa4 distribution (taking more than 30 seconds)SKIPPED ksone distribution (taking more than 30 seconds)
# SKIPPED loguniform distribution (taking more than 30 seconds)
# SKIPPED levy_stable distribution (taking more than 30 seconds)
# SKIPPED loggamma distribution (taking more than 30 seconds)
# SKIPPED loglaplace distribution (taking more than 30 seconds)
# SKIPPED lognorm distribution (taking more than 30 seconds)
# SKIPPED lomax distribution (taking more than 30 seconds)
# SKIPPED mielke distribution (taking more than 30 seconds)
# SKIPPED nakagami distribution (taking more than 30 seconds)
# SKIPPED ncf distribution (taking more than 30 seconds)
# SKIPPED nct distribution (taking more than 30 seconds)
# SKIPPED reciprocal distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  73%|███████▎  | 80/110 [04:10<01:13,  2.45s/it]SKIPPED ncx2 distribution (taking more than 30 seconds)SKIPPED rv_continuous distribution (taking more than 30 seconds)
# SKIPPED rv_histogram distribution (taking more than 30 seconds)
# SKIPPED norminvgauss distribution (taking more than 30 seconds)
# SKIPPED pearson3 distribution (taking more than 30 seconds)
# SKIPPED powerlognorm distribution (taking more than 30 seconds)
# SKIPPED powernorm distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  80%|████████  | 88/110 [04:34<01:39,  4.54s/it]SKIPPED rdist distribution (taking more than 30 seconds)SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# SKIPPED rice distribution (taking more than 30 seconds)
# SKIPPED skewcauchy distribution (taking more than 30 seconds)
# SKIPPED skewnorm distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED t distribution (taking more than 30 seconds)
# SKIPPED trapezoid distribution (taking more than 30 seconds)
# SKIPPED trapz distribution (taking more than 30 seconds)
#
# SKIPPED triang distribution (taking more than 30 seconds)SKIPPED truncnorm distribution (taking more than 30 seconds)
# SKIPPED truncpareto distribution (taking more than 30 seconds)
# SKIPPED truncweibull_min distribution (taking more than 30 seconds)
# SKIPPED tukeylambda distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
# SKIPPED vonmises_line distribution (taking more than 30 seconds)
# SKIPPED weibull_max distribution (taking more than 30 seconds)
# SKIPPED wrapcauchy distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [05:50<00:00,  3.19s/it]
#   8%|▊         | 10/120 [19:35<5:43:22, 187.30s/it]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED _fit distribution (taking more than 30 seconds)
# SKIPPED arcsine distribution (taking more than 30 seconds)
#
# SKIPPED alpha distribution (taking more than 30 seconds)
# Fitting 110 distributions:   3%|▎         | 3/110 [00:33<21:01, 11.79s/it]SKIPPED bradford distribution (taking more than 30 seconds)SKIPPED argus distribution (taking more than 30 seconds)
# SKIPPED betaprime distribution (taking more than 30 seconds)
#
# SKIPPED beta distribution (taking more than 30 seconds)SKIPPED burr distribution (taking more than 30 seconds)
# SKIPPED burr12 distribution (taking more than 30 seconds)
# SKIPPED chi distribution (taking more than 30 seconds)
#
# SKIPPED chi2 distribution (taking more than 30 seconds)
# SKIPPED crystalball distribution (taking more than 30 seconds)
# Fitting 110 distributions:  14%|█▎        | 15/110 [01:04<05:23,  3.40s/it]SKIPPED dgamma distribution (taking more than 30 seconds)SKIPPED dweibull distribution (taking more than 30 seconds)
# SKIPPED erlang distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED exponpow distribution (taking more than 30 seconds)
# SKIPPED exponweib distribution (taking more than 30 seconds)
#
# SKIPPED f distribution (taking more than 30 seconds)
# SKIPPED fatiguelife distribution (taking more than 30 seconds)SKIPPED fisk distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  21%|██        | 23/110 [01:36<06:50,  4.72s/it]SKIPPED foldcauchy distribution (taking more than 30 seconds)SKIPPED foldnorm distribution (taking more than 30 seconds)
# SKIPPED gamma distribution (taking more than 30 seconds)
# SKIPPED gausshyper distribution (taking more than 30 seconds)
# SKIPPED genexpon distribution (taking more than 30 seconds)
# SKIPPED genextreme distribution (taking more than 30 seconds)
# SKIPPED gengamma distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  29%|██▉       | 32/110 [02:06<04:29,  3.46s/it]SKIPPED genhalflogistic distribution (taking more than 30 seconds)
# SKIPPED genhyperbolic distribution (taking more than 30 seconds)SKIPPED geninvgauss distribution (taking more than 30 seconds)
#
# SKIPPED genlogistic distribution (taking more than 30 seconds)SKIPPED gennorm distribution (taking more than 30 seconds)
# SKIPPED genpareto distribution (taking more than 30 seconds)
# SKIPPED gibrat distribution (taking more than 30 seconds)
# SKIPPED gilbrat distribution (taking more than 30 seconds)
# SKIPPED gompertz distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  41%|████      | 45/110 [02:42<02:58,  2.74s/it]SKIPPED halfgennorm distribution (taking more than 30 seconds)SKIPPED halflogistic distribution (taking more than 30 seconds)
# SKIPPED invgauss distribution (taking more than 30 seconds)
# SKIPPED kstwo distribution (taking more than 30 seconds)
#
# SKIPPED invgamma distribution (taking more than 30 seconds)
# Fitting 110 distributions:  45%|████▌     | 50/110 [03:06<04:49,  4.82s/it]SKIPPED invweibull distribution (taking more than 30 seconds)
# Fitting 110 distributions:  46%|████▋     | 51/110 [03:07<03:33,  3.63s/it]SKIPPED johnsonsb distribution (taking more than 30 seconds)SKIPPED johnsonsu distribution (taking more than 30 seconds)
# SKIPPED kappa3 distribution (taking more than 30 seconds)
# SKIPPED kappa4 distribution (taking more than 30 seconds)
# SKIPPED ksone distribution (taking more than 30 seconds)
#
# SKIPPED loguniform distribution (taking more than 30 seconds)SKIPPED levy_stable distribution (taking more than 30 seconds)
# SKIPPED loggamma distribution (taking more than 30 seconds)
# SKIPPED loglaplace distribution (taking more than 30 seconds)
# SKIPPED lognorm distribution (taking more than 30 seconds)
# SKIPPED lomax distribution (taking more than 30 seconds)
# SKIPPED mielke distribution (taking more than 30 seconds)
# SKIPPED nakagami distribution (taking more than 30 seconds)
# SKIPPED ncf distribution (taking more than 30 seconds)
#
# SKIPPED nct distribution (taking more than 30 seconds)SKIPPED ncx2 distribution (taking more than 30 seconds)
#
# SKIPPED reciprocal distribution (taking more than 30 seconds)
# SKIPPED rv_continuous distribution (taking more than 30 seconds)
# SKIPPED rv_histogram distribution (taking more than 30 seconds)SKIPPED norminvgauss distribution (taking more than 30 seconds)
# SKIPPED pearson3 distribution (taking more than 30 seconds)
# SKIPPED powerlognorm distribution (taking more than 30 seconds)
# SKIPPED powernorm distribution (taking more than 30 seconds)
# SKIPPED rdist distribution (taking more than 30 seconds)
# SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# SKIPPED rice distribution (taking more than 30 seconds)
#
# SKIPPED semicircular distribution (taking more than 30 seconds)SKIPPED skewcauchy distribution (taking more than 30 seconds)
# SKIPPED skewnorm distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED t distribution (taking more than 30 seconds)
#
# SKIPPED trapezoid distribution (taking more than 30 seconds)
# SKIPPED trapz distribution (taking more than 30 seconds)SKIPPED triang distribution (taking more than 30 seconds)
# SKIPPED truncnorm distribution (taking more than 30 seconds)
# SKIPPED truncpareto distribution (taking more than 30 seconds)
# SKIPPED truncweibull_min distribution (taking more than 30 seconds)
# SKIPPED tukeylambda distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  96%|█████████▋| 106/110 [05:44<00:18,  4.58s/it]SKIPPED vonmises_line distribution (taking more than 30 seconds)SKIPPED weibull_max distribution (taking more than 30 seconds)
# SKIPPED weibull_min distribution (taking more than 30 seconds)
# SKIPPED wrapcauchy distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [06:00<00:00,  3.27s/it]
#   9%|▉         | 11/120 [25:37<7:17:29, 240.82s/it]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED _fit distribution (taking more than 30 seconds)
# SKIPPED alpha distribution (taking more than 30 seconds)
# SKIPPED betaprime distribution (taking more than 30 seconds)
#
# SKIPPED beta distribution (taking more than 30 seconds)
# SKIPPED bradford distribution (taking more than 30 seconds)
# Fitting 110 distributions:   4%|▎         | 4/110 [00:34<12:28,  7.06s/it]SKIPPED arcsine distribution (taking more than 30 seconds)
#
# SKIPPED argus distribution (taking more than 30 seconds)
# Fitting 110 distributions:   5%|▍         | 5/110 [00:34<08:11,  4.68s/it]SKIPPED burr distribution (taking more than 30 seconds)
# Fitting 110 distributions:  12%|█▏        | 13/110 [00:56<05:27,  3.38s/it]SKIPPED burr12 distribution (taking more than 30 seconds)SKIPPED chi distribution (taking more than 30 seconds)
# SKIPPED chi2 distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  15%|█▍        | 16/110 [01:04<05:16,  3.37s/it]SKIPPED crystalball distribution (taking more than 30 seconds)SKIPPED exponpow distribution (taking more than 30 seconds)
# SKIPPED exponweib distribution (taking more than 30 seconds)
# SKIPPED f distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED fatiguelife distribution (taking more than 30 seconds)
#
# SKIPPED fisk distribution (taking more than 30 seconds)SKIPPED foldcauchy distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  23%|██▎       | 25/110 [01:36<04:38,  3.28s/it]SKIPPED foldnorm distribution (taking more than 30 seconds)SKIPPED gausshyper distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  26%|██▋       | 29/110 [01:57<09:03,  6.71s/it]SKIPPED genexpon distribution (taking more than 30 seconds)SKIPPED genextreme distribution (taking more than 30 seconds)
# SKIPPED gengamma distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  29%|██▉       | 32/110 [02:05<05:47,  4.45s/it]SKIPPED genhalflogistic distribution (taking more than 30 seconds)
# SKIPPED genhyperbolic distribution (taking more than 30 seconds)
# Fitting 110 distributions:  30%|███       | 33/110 [02:06<04:23,  3.42s/it]SKIPPED geninvgauss distribution (taking more than 30 seconds)
# SKIPPED genlogistic distribution (taking more than 30 seconds)
# SKIPPED genpareto distribution (taking more than 30 seconds)
# SKIPPED gibrat distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  38%|███▊      | 42/110 [02:35<04:30,  3.97s/it]SKIPPED gilbrat distribution (taking more than 30 seconds)
#
# SKIPPED gompertz distribution (taking more than 30 seconds)SKIPPED halfgennorm distribution (taking more than 30 seconds)
# SKIPPED halflogistic distribution (taking more than 30 seconds)
# SKIPPED invgamma distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  45%|████▍     | 49/110 [03:01<06:35,  6.48s/it]SKIPPED kstwo distribution (taking more than 30 seconds)
# SKIPPED invgauss distribution (taking more than 30 seconds)
# SKIPPED invweibull distribution (taking more than 30 seconds)
# SKIPPED johnsonsb distribution (taking more than 30 seconds)
# SKIPPED johnsonsu distribution (taking more than 30 seconds)
# SKIPPED kappa3 distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  50%|█████     | 55/110 [03:10<01:58,  2.16s/it]SKIPPED kappa4 distribution (taking more than 30 seconds)SKIPPED ksone distribution (taking more than 30 seconds)
# SKIPPED loguniform distribution (taking more than 30 seconds)
# SKIPPED levy distribution (taking more than 30 seconds)
# SKIPPED levy_stable distribution (taking more than 30 seconds)
#
# SKIPPED loggamma distribution (taking more than 30 seconds)SKIPPED loglaplace distribution (taking more than 30 seconds)
#
# SKIPPED lognorm distribution (taking more than 30 seconds)SKIPPED lomax distribution (taking more than 30 seconds)
# SKIPPED mielke distribution (taking more than 30 seconds)
# SKIPPED nakagami distribution (taking more than 30 seconds)
# SKIPPED ncf distribution (taking more than 30 seconds)
# SKIPPED nct distribution (taking more than 30 seconds)
# SKIPPED ncx2 distribution (taking more than 30 seconds)
# SKIPPED reciprocal distribution (taking more than 30 seconds)
# SKIPPED rv_continuous distribution (taking more than 30 seconds)
#
# SKIPPED rv_histogram distribution (taking more than 30 seconds)
# SKIPPED norminvgauss distribution (taking more than 30 seconds)SKIPPED pearson3 distribution (taking more than 30 seconds)
# SKIPPED powerlognorm distribution (taking more than 30 seconds)
# SKIPPED powernorm distribution (taking more than 30 seconds)
# SKIPPED rdist distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  80%|████████  | 88/110 [04:42<01:22,  3.74s/it]SKIPPED recipinvgauss distribution (taking more than 30 seconds)SKIPPED rice distribution (taking more than 30 seconds)
# SKIPPED skewcauchy distribution (taking more than 30 seconds)
# SKIPPED skewnorm distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED t distribution (taking more than 30 seconds)
# SKIPPED trapezoid distribution (taking more than 30 seconds)
# SKIPPED trapz distribution (taking more than 30 seconds)
# SKIPPED triang distribution (taking more than 30 seconds)
# SKIPPED truncexpon distribution (taking more than 30 seconds)
# SKIPPED truncnorm distribution (taking more than 30 seconds)
# SKIPPED truncpareto distribution (taking more than 30 seconds)
# SKIPPED truncweibull_min distribution (taking more than 30 seconds)
# SKIPPED tukeylambda distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
# SKIPPED vonmises_line distribution (taking more than 30 seconds)
# SKIPPED wald distribution (taking more than 30 seconds)
# SKIPPED weibull_max distribution (taking more than 30 seconds)
# SKIPPED wrapcauchy distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [05:59<00:00,  3.27s/it]
#  10%|█         | 12/120 [31:40<8:20:01, 277.79s/it]SKIPPED _fit distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED anglit distribution (taking more than 30 seconds)
#
# SKIPPED argus distribution (taking more than 30 seconds)
# SKIPPED beta distribution (taking more than 30 seconds)
# Fitting 110 distributions:   2%|▏         | 2/110 [00:33<33:42, 18.72s/it]SKIPPED betaprime distribution (taking more than 30 seconds)SKIPPED alpha distribution (taking more than 30 seconds)
#
# SKIPPED arcsine distribution (taking more than 30 seconds)SKIPPED burr distribution (taking more than 30 seconds)
# SKIPPED bradford distribution (taking more than 30 seconds)
# SKIPPED burr12 distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  13%|█▎        | 14/110 [01:03<05:20,  3.33s/it]SKIPPED chi distribution (taking more than 30 seconds)SKIPPED chi2 distribution (taking more than 30 seconds)
#
# SKIPPED crystalball distribution (taking more than 30 seconds)SKIPPED erlang distribution (taking more than 30 seconds)
# SKIPPED exponpow distribution (taking more than 30 seconds)
# SKIPPED exponweib distribution (taking more than 30 seconds)
# SKIPPED f distribution (taking more than 30 seconds)
# SKIPPED fatiguelife distribution (taking more than 30 seconds)
#
# SKIPPED fisk distribution (taking more than 30 seconds)SKIPPED foldcauchy distribution (taking more than 30 seconds)
# SKIPPED foldnorm distribution (taking more than 30 seconds)
# SKIPPED gamma distribution (taking more than 30 seconds)
# SKIPPED gausshyper distribution (taking more than 30 seconds)
# SKIPPED genexpon distribution (taking more than 30 seconds)
#
# SKIPPED genextreme distribution (taking more than 30 seconds)
# Fitting 110 distributions:  27%|██▋       | 30/110 [02:04<06:36,  4.95s/it]SKIPPED gengamma distribution (taking more than 30 seconds)SKIPPED genhalflogistic distribution (taking more than 30 seconds)
#
# SKIPPED genhyperbolic distribution (taking more than 30 seconds)
# Fitting 110 distributions:  29%|██▉       | 32/110 [02:06<03:55,  3.02s/it]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED geninvgauss distribution (taking more than 30 seconds)
# SKIPPED genlogistic distribution (taking more than 30 seconds)
# SKIPPED genpareto distribution (taking more than 30 seconds)
#
# SKIPPED gibrat distribution (taking more than 30 seconds)SKIPPED gilbrat distribution (taking more than 30 seconds)
# SKIPPED gompertz distribution (taking more than 30 seconds)
# SKIPPED halfcauchy distribution (taking more than 30 seconds)
# SKIPPED halfgennorm distribution (taking more than 30 seconds)
# SKIPPED halflogistic distribution (taking more than 30 seconds)
# SKIPPED invgamma distribution (taking more than 30 seconds)
#
# SKIPPED invgauss distribution (taking more than 30 seconds)
# Fitting 110 distributions:  45%|████▍     | 49/110 [03:06<05:46,  5.68s/it]SKIPPED invweibull distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  45%|████▌     | 50/110 [03:06<04:09,  4.15s/it]SKIPPED kstwo distribution (taking more than 30 seconds)SKIPPED johnsonsb distribution (taking more than 30 seconds)
# SKIPPED johnsonsu distribution (taking more than 30 seconds)
# SKIPPED kappa3 distribution (taking more than 30 seconds)
# SKIPPED kappa4 distribution (taking more than 30 seconds)
# SKIPPED ksone distribution (taking more than 30 seconds)
# SKIPPED loguniform distribution (taking more than 30 seconds)
# SKIPPED levy_l distribution (taking more than 30 seconds)
# SKIPPED levy_stable distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  59%|█████▉    | 65/110 [03:48<02:50,  3.79s/it]SKIPPED loggamma distribution (taking more than 30 seconds)SKIPPED loglaplace distribution (taking more than 30 seconds)
#
# SKIPPED lognorm distribution (taking more than 30 seconds)SKIPPED lomax distribution (taking more than 30 seconds)
# SKIPPED mielke distribution (taking more than 30 seconds)
#
# SKIPPED ncf distribution (taking more than 30 seconds)SKIPPED nct distribution (taking more than 30 seconds)
#
# SKIPPED ncx2 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  72%|███████▏  | 79/110 [04:25<01:12,  2.34s/it]SKIPPED norminvgauss distribution (taking more than 30 seconds)SKIPPED rv_continuous distribution (taking more than 30 seconds)
# SKIPPED rv_histogram distribution (taking more than 30 seconds)
#
# SKIPPED reciprocal distribution (taking more than 30 seconds)SKIPPED pearson3 distribution (taking more than 30 seconds)
# SKIPPED powerlognorm distribution (taking more than 30 seconds)
# SKIPPED powernorm distribution (taking more than 30 seconds)
# SKIPPED rdist distribution (taking more than 30 seconds)
# SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# SKIPPED rice distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  82%|████████▏ | 90/110 [04:56<01:02,  3.14s/it]SKIPPED semicircular distribution (taking more than 30 seconds)SKIPPED skewcauchy distribution (taking more than 30 seconds)
# SKIPPED skewnorm distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED t distribution (taking more than 30 seconds)
# SKIPPED trapezoid distribution (taking more than 30 seconds)
# SKIPPED trapz distribution (taking more than 30 seconds)
# SKIPPED triang distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  90%|█████████ | 99/110 [05:26<00:28,  2.61s/it]SKIPPED truncexpon distribution (taking more than 30 seconds)SKIPPED truncnorm distribution (taking more than 30 seconds)
# SKIPPED truncpareto distribution (taking more than 30 seconds)
# SKIPPED truncweibull_min distribution (taking more than 30 seconds)
# SKIPPED tukeylambda distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
# SKIPPED vonmises_line distribution (taking more than 30 seconds)
# SKIPPED weibull_max distribution (taking more than 30 seconds)
# SKIPPED wrapcauchy distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [06:07<00:00,  3.34s/it]
#  11%|█         | 13/120 [37:50<9:05:39, 305.98s/it]SKIPPED _fit distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#
# SKIPPED arcsine distribution (taking more than 30 seconds)
# Fitting 110 distributions:   2%|▏         | 2/110 [00:31<32:51, 18.26s/it]SKIPPED alpha distribution (taking more than 30 seconds)SKIPPED argus distribution (taking more than 30 seconds)
#
# SKIPPED beta distribution (taking more than 30 seconds)
# Fitting 110 distributions:   3%|▎         | 3/110 [00:32<18:31, 10.39s/it]SKIPPED bradford distribution (taking more than 30 seconds)SKIPPED betaprime distribution (taking more than 30 seconds)
# SKIPPED burr distribution (taking more than 30 seconds)
# SKIPPED burr12 distribution (taking more than 30 seconds)
# SKIPPED chi distribution (taking more than 30 seconds)
# SKIPPED chi2 distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  13%|█▎        | 14/110 [01:02<04:58,  3.11s/it]SKIPPED crystalball distribution (taking more than 30 seconds)SKIPPED dgamma distribution (taking more than 30 seconds)
# SKIPPED dweibull distribution (taking more than 30 seconds)
# SKIPPED erlang distribution (taking more than 30 seconds)
# SKIPPED exponnorm distribution (taking more than 30 seconds)
# SKIPPED exponpow distribution (taking more than 30 seconds)
# SKIPPED exponweib distribution (taking more than 30 seconds)
#
# SKIPPED f distribution (taking more than 30 seconds)SKIPPED fatiguelife distribution (taking more than 30 seconds)
#
# SKIPPED fisk distribution (taking more than 30 seconds)
# SKIPPED foldcauchy distribution (taking more than 30 seconds)SKIPPED foldnorm distribution (taking more than 30 seconds)
# SKIPPED gamma distribution (taking more than 30 seconds)
# SKIPPED gausshyper distribution (taking more than 30 seconds)
# SKIPPED genexpon distribution (taking more than 30 seconds)
#
# SKIPPED genextreme distribution (taking more than 30 seconds)
# Fitting 110 distributions:  27%|██▋       | 30/110 [02:04<05:36,  4.21s/it]SKIPPED gengamma distribution (taking more than 30 seconds)
# SKIPPED genhalflogistic distribution (taking more than 30 seconds)SKIPPED genhyperbolic distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED geninvgauss distribution (taking more than 30 seconds)
# SKIPPED genlogistic distribution (taking more than 30 seconds)
# SKIPPED gennorm distribution (taking more than 30 seconds)
# SKIPPED genpareto distribution (taking more than 30 seconds)
# SKIPPED gibrat distribution (taking more than 30 seconds)
# SKIPPED gilbrat distribution (taking more than 30 seconds)
#
# SKIPPED gompertz distribution (taking more than 30 seconds)SKIPPED halfcauchy distribution (taking more than 30 seconds)
# SKIPPED halfgennorm distribution (taking more than 30 seconds)
# SKIPPED halflogistic distribution (taking more than 30 seconds)
# SKIPPED invgamma distribution (taking more than 30 seconds)
#
# SKIPPED invgauss distribution (taking more than 30 seconds)
# SKIPPED kstwo distribution (taking more than 30 seconds)
# ...
# SKIPPED gompertz distribution (taking more than 30 seconds)SKIPPED gumbel_l distribution (taking more than 30 seconds)
# SKIPPED gumbel_r distribution (taking more than 30 seconds)
#
# SKIPPED halfcauchy distribution (taking more than 30 seconds)
# SKIPPED halfgennorm distribution (taking more than 30 seconds)SKIPPED halflogistic distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  31%|███       | 34/110 [06:50<14:10, 11.19s/it]SKIPPED halfnorm distribution (taking more than 30 seconds)
# Fitting 110 distributions:  32%|███▏      | 35/110 [07:03<15:29, 12.39s/it]SKIPPED hypsecant distribution (taking more than 30 seconds)
# SKIPPED invgamma distribution (taking more than 30 seconds)
# Fitting 110 distributions:  34%|███▎      | 37/110 [07:28<16:03, 13.20s/it]SKIPPED invgauss distribution (taking more than 30 seconds)SKIPPED invweibull distribution (taking more than 30 seconds)
# SKIPPED johnsonsb distribution (taking more than 30 seconds)
# SKIPPED johnsonsu distribution (taking more than 30 seconds)
# SKIPPED kappa3 distribution (taking more than 30 seconds)
# SKIPPED kappa4 distribution (taking more than 30 seconds)
#
# SKIPPED kstwo distribution (taking more than 30 seconds)
# Fitting 110 distributions:  39%|███▉      | 43/110 [08:42<13:10, 11.80s/it]SKIPPED ksone distribution (taking more than 30 seconds)
# SKIPPED kstwobign distribution (taking more than 30 seconds)
# Fitting 110 distributions:  43%|████▎     | 47/110 [09:35<14:03, 13.39s/it]SKIPPED laplace_asymmetric distribution (taking more than 30 seconds)
# SKIPPED levy distribution (taking more than 30 seconds)
# Fitting 110 distributions:  45%|████▌     | 50/110 [10:02<10:27, 10.45s/it]SKIPPED levy_l distribution (taking more than 30 seconds)
# Fitting 110 distributions:  46%|████▋     | 51/110 [10:15<10:25, 10.61s/it]SKIPPED levy_stable distribution (taking more than 30 seconds)
# Fitting 110 distributions:  47%|████▋     | 52/110 [10:26<10:44, 11.12s/it]SKIPPED loggamma distribution (taking more than 30 seconds)SKIPPED logistic distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  49%|████▉     | 54/110 [10:40<08:36,  9.22s/it]SKIPPED loglaplace distribution (taking more than 30 seconds)SKIPPED lognorm distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  51%|█████     | 56/110 [11:03<08:45,  9.74s/it]SKIPPED loguniform distribution (taking more than 30 seconds)SKIPPED lomax distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  52%|█████▏    | 57/110 [11:18<09:45, 11.05s/it]SKIPPED maxwell distribution (taking more than 30 seconds)
# SKIPPED mielke distribution (taking more than 30 seconds)
# SKIPPED moyal distribution (taking more than 30 seconds)SKIPPED nakagami distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  55%|█████▌    | 61/110 [12:00<09:07, 11.18s/it]SKIPPED ncf distribution (taking more than 30 seconds)
# SKIPPED nct distribution (taking more than 30 seconds)
# SKIPPED ncx2 distribution (taking more than 30 seconds)SKIPPED norminvgauss distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  60%|██████    | 66/110 [13:00<08:35, 11.72s/it]SKIPPED pareto distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  61%|██████    | 67/110 [13:10<08:39, 12.08s/it]SKIPPED pearson3 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  62%|██████▏   | 68/110 [13:23<08:14, 11.77s/it]SKIPPED powerlaw distribution (taking more than 30 seconds)SKIPPED powerlognorm distribution (taking more than 30 seconds)
#
# SKIPPED powernorm distribution (taking more than 30 seconds)
# Fitting 110 distributions:  65%|██████▌   | 72/110 [14:02<05:55,  9.37s/it]SKIPPED rayleigh distribution (taking more than 30 seconds)SKIPPED rdist distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  66%|██████▋   | 73/110 [14:13<07:01, 11.38s/it]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# Fitting 110 distributions:  67%|██████▋   | 74/110 [14:21<06:21, 10.60s/it]SKIPPED recipinvgauss distribution (taking more than 30 seconds)SKIPPED rv_continuous distribution (taking more than 30 seconds)
#
# SKIPPED reciprocal distribution (taking more than 30 seconds)
# Fitting 110 distributions:  68%|██████▊   | 75/110 [14:36<05:47,  9.92s/it]SKIPPED rv_histogram distribution (taking more than 30 seconds)
# SKIPPED rice distribution (taking more than 30 seconds)
# SKIPPED semicircular distribution (taking more than 30 seconds)
# SKIPPED skewcauchy distribution (taking more than 30 seconds)SKIPPED skewnorm distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
#
# SKIPPED t distribution (taking more than 30 seconds)
# Fitting 110 distributions:  76%|███████▋  | 84/110 [16:08<04:03,  9.37s/it]SKIPPED trapezoid distribution (taking more than 30 seconds)
#
# SKIPPED trapz distribution (taking more than 30 seconds)SKIPPED triang distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  78%|███████▊  | 86/110 [16:34<04:13, 10.55s/it]SKIPPED truncexpon distribution (taking more than 30 seconds)SKIPPED truncnorm distribution (taking more than 30 seconds)
#
# SKIPPED truncpareto distribution (taking more than 30 seconds)SKIPPED truncweibull_min distribution (taking more than 30 seconds)
# IOStream.flush timed out
#
# SKIPPED tukeylambda distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)SKIPPED vonmises_line distribution (taking more than 30 seconds)
# SKIPPED wald distribution (taking more than 30 seconds)
# SKIPPED weibull_max distribution (taking more than 30 seconds)
# SKIPPED weibull_min distribution (taking more than 30 seconds)
#
# Fitting 110 distributions: 100%|██████████| 110/110 [20:49<00:00, 11.36s/it]KIPPED wrapcauchy distribution (taking more than 30 seconds)
#  57%|█████▊    | 69/120 [12:20:46<18:00:41, 1271.41s/it]SKIPPED _fit distribution (taking more than 30 seconds)
# SKIPPED anglit distribution (taking more than 30 seconds)
# SKIPPED arcsine distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:   2%|▏         | 2/110 [00:58<53:01, 29.46s/it]SKIPPED alpha distribution (taking more than 30 seconds)SKIPPED argus distribution (taking more than 30 seconds)
#
# SKIPPED beta distribution (taking more than 30 seconds)
# Fitting 110 distributions:   3%|▎         | 3/110 [01:19<37:27, 21.01s/it]SKIPPED betaprime distribution (taking more than 30 seconds)SKIPPED bradford distribution (taking more than 30 seconds)
# SKIPPED burr distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:   4%|▎         | 4/110 [01:31<37:20, 21.14s/it]SKIPPED burr12 distribution (taking more than 30 seconds)SKIPPED cauchy distribution (taking more than 30 seconds)
#
# SKIPPED chi distribution (taking more than 30 seconds)
# SKIPPED chi2 distribution (taking more than 30 seconds)
# SKIPPED cosine distribution (taking more than 30 seconds)SKIPPED crystalball distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:   7%|▋         | 8/110 [02:05<18:50, 11.09s/it]SKIPPED dweibull distribution (taking more than 30 seconds)
# SKIPPED dgamma distribution (taking more than 30 seconds)
# SKIPPED erlang distribution (taking more than 30 seconds)
# SKIPPED exponnorm distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:   8%|▊         | 9/110 [02:24<21:45, 12.93s/it]SKIPPED exponpow distribution (taking more than 30 seconds)SKIPPED exponweib distribution (taking more than 30 seconds)
#
# SKIPPED f distribution (taking more than 30 seconds)SKIPPED fatiguelife distribution (taking more than 30 seconds)
# SKIPPED fisk distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  12%|█▏        | 13/110 [03:13<18:42, 11.57s/it]SKIPPED foldcauchy distribution (taking more than 30 seconds)
# SKIPPED foldnorm distribution (taking more than 30 seconds)
# Fitting 110 distributions:  14%|█▎        | 15/110 [03:29<17:34, 11.10s/it]SKIPPED gamma distribution (taking more than 30 seconds)SKIPPED gausshyper distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  15%|█▌        | 17/110 [03:52<17:21, 11.20s/it]SKIPPED genexpon distribution (taking more than 30 seconds)
# SKIPPED genextreme distribution (taking more than 30 seconds)
#
# SKIPPED gengamma distribution (taking more than 30 seconds)
# Fitting 110 distributions:  18%|█▊        | 20/110 [04:20<13:27,  8.98s/it]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,SKIPPED genhalflogistic distribution (taking more than 30 seconds)
# SKIPPED genhyperbolic distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  20%|██        | 22/110 [04:44<17:48, 12.14s/it]SKIPPED geninvgauss distribution (taking more than 30 seconds)
# Fitting 110 distributions:  21%|██        | 23/110 [04:56<16:15, 11.21s/it]SKIPPED genlogistic distribution (taking more than 30 seconds)
# SKIPPED gennorm distribution (taking more than 30 seconds)
# SKIPPED genpareto distribution (taking more than 30 seconds)SKIPPED gibrat distribution (taking more than 30 seconds)
#
# SKIPPED gilbrat distribution (taking more than 30 seconds)SKIPPED gompertz distribution (taking more than 30 seconds)
# SKIPPED gumbel_l distribution (taking more than 30 seconds)
# SKIPPED gumbel_r distribution (taking more than 30 seconds)
# SKIPPED halfcauchy distribution (taking more than 30 seconds)
# SKIPPED halfgennorm distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  31%|███       | 34/110 [07:00<14:01, 11.08s/it]SKIPPED halflogistic distribution (taking more than 30 seconds)
#
# SKIPPED halfnorm distribution (taking more than 30 seconds)
# SKIPPED hypsecant distribution (taking more than 30 seconds)
# SKIPPED invgamma distribution (taking more than 30 seconds)SKIPPED invgauss distribution (taking more than 30 seconds)
# SKIPPED invweibull distribution (taking more than 30 seconds)
# SKIPPED johnsonsb distribution (taking more than 30 seconds)
#
# SKIPPED johnsonsu distribution (taking more than 30 seconds)
# Fitting 110 distributions:  38%|███▊      | 42/110 [08:19<10:41,  9.43s/it]SKIPPED kappa3 distribution (taking more than 30 seconds)
# SKIPPED kstwo distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  40%|████      | 44/110 [08:34<09:04,  8.25s/it]SKIPPED kappa4 distribution (taking more than 30 seconds)
#
# SKIPPED ksone distribution (taking more than 30 seconds)
# Fitting 110 distributions:  43%|████▎     | 47/110 [08:57<08:35,  8.19s/it]SKIPPED kstwobign distribution (taking more than 30 seconds)SKIPPED laplace_asymmetric distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  45%|████▍     | 49/110 [09:15<08:03,  7.93s/it]SKIPPED levy distribution (taking more than 30 seconds)
# SKIPPED levy_l distribution (taking more than 30 seconds)
# Fitting 110 distributions:  46%|████▋     | 51/110 [09:36<08:02,  8.17s/it]SKIPPED levy_stable distribution (taking more than 30 seconds)
# SKIPPED loggamma distribution (taking more than 30 seconds)
# Fitting 110 distributions:  48%|████▊     | 53/110 [09:55<09:12,  9.69s/it]SKIPPED logistic distribution (taking more than 30 seconds)
# SKIPPED loglaplace distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  50%|█████     | 55/110 [10:12<08:33,  9.33s/it]SKIPPED lognorm distribution (taking more than 30 seconds)
# SKIPPED loguniform distribution (taking more than 30 seconds)SKIPPED lomax distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  53%|█████▎    | 58/110 [10:38<07:39,  8.84s/it]SKIPPED maxwell distribution (taking more than 30 seconds)
# SKIPPED mielke distribution (taking more than 30 seconds)SKIPPED moyal distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  55%|█████▍    | 60/110 [11:06<09:02, 10.85s/it]SKIPPED nakagami distribution (taking more than 30 seconds)
# SKIPPED ncf distribution (taking more than 30 seconds)
# SKIPPED nct distribution (taking more than 30 seconds)
# SKIPPED ncx2 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  59%|█████▉    | 65/110 [12:08<08:39, 11.55s/it]SKIPPED norminvgauss distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  60%|██████    | 66/110 [12:21<09:20, 12.73s/it]SKIPPED pareto distribution (taking more than 30 seconds)SKIPPED pearson3 distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  61%|██████    | 67/110 [12:46<11:00, 15.37s/it]SKIPPED powerlaw distribution (taking more than 30 seconds)
# SKIPPED powerlognorm distribution (taking more than 30 seconds)
# Fitting 110 distributions:  64%|██████▎   | 70/110 [13:28<09:58, 14.96s/it]SKIPPED powernorm distribution (taking more than 30 seconds)
# SKIPPED rayleigh distribution (taking more than 30 seconds)SKIPPED rdist distribution (taking more than 30 seconds)
# SKIPPED recipinvgauss distribution (taking more than 30 seconds)
#
# SKIPPED rv_continuous distribution (taking more than 30 seconds)SKIPPED reciprocal distribution (taking more than 30 seconds)
#
# SKIPPED rv_histogram distribution (taking more than 30 seconds)SKIPPED rice distribution (taking more than 30 seconds)
#
# SKIPPED semicircular distribution (taking more than 30 seconds)SKIPPED skewcauchy distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  73%|███████▎  | 80/110 [15:16<05:29, 10.97s/it]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED skewnorm distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  74%|███████▎  | 81/110 [15:26<05:14, 10.83s/it]SKIPPED studentized_range distribution (taking more than 30 seconds)
#
# SKIPPED t distribution (taking more than 30 seconds)
# SKIPPED trapezoid distribution (taking more than 30 seconds)SKIPPED trapz distribution (taking more than 30 seconds)
# SKIPPED triang distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  78%|███████▊  | 86/110 [16:25<04:40, 11.67s/it]SKIPPED truncexpon distribution (taking more than 30 seconds)
# SKIPPED truncnorm distribution (taking more than 30 seconds)SKIPPED truncpareto distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  81%|████████  | 89/110 [17:03<04:30, 12.87s/it]SKIPPED truncweibull_min distribution (taking more than 30 seconds)SKIPPED tukeylambda distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  84%|████████▎ | 92/110 [17:46<03:56, 13.13s/it]SKIPPED vonmises distribution (taking more than 30 seconds)SKIPPED vonmises_line distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  85%|████████▌ | 94/110 [18:10<03:09, 11.83s/it]SKIPPED wald distribution (taking more than 30 seconds)SKIPPED weibull_max distribution (taking more than 30 seconds)
#
# SKIPPED weibull_min distribution (taking more than 30 seconds)SKIPPED wrapcauchy distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [21:22<00:00, 11.66s/it]
#  58%|█████▊    | 70/120 [12:42:48<17:52:13, 1286.67s/it]SKIPPED _fit distribution (taking more than 30 seconds)
# SKIPPED arcsine distribution (taking more than 30 seconds)
# Fitting 110 distributions:   1%|          | 1/110 [00:51<1:33:12, 51.31s/it]

# %%
pkls = []
for p in range(1,3):
    read_file = f'../results/top_distributions_day_{p}.pkl'
    pkls.append(pd.read_pickle(read_file))
df_ks_values = pd.concat(pkls, ignore_index=True)

mean_pvalues = {}
for dist in df_ks_values:
    mean_pvalues[dist] = (np.nanmean(df_ks_values[dist]), df_ks_values[dist].isna().sum())
mean_pvalues = dict(sorted(mean_pvalues.items(), key=lambda x:x[1][0], reverse=True))
mean_pvalues
# Out:
# /tmp/ipykernel_144033/4208943712.py:9: RuntimeWarning: Mean of empty slice
#   mean_pvalues[dist] = (np.nanmean(df_ks_values[dist]), df_ks_values[dist].isna().sum())
# {'johnsonsu': (0.4184450261403081, 39),
#  'norminvgauss': (0.41768855600666793, 39),
#  'genhyperbolic': (0.39888860450127184, 39),
#  'fisk': (0.3971200230652554, 39),
#  'genlogistic': (0.3930355153854472, 39),
#  'burr12': (0.3904928400040852, 39),
#  'burr': (0.386549213222448, 40),
#  'nct': (0.370730738615346, 39),
#  'alpha': (0.32159445986396185, 39),
#  'invgamma': (0.3119981384673507, 39),
#  'powerlognorm': (0.30619956533112613, 39),
#  'betaprime': (0.30599643082796363, 39),
#  'skewnorm': (0.3026532308209264, 39),
#  'lognorm': (0.30115885217044575, 39),
#  'exponnorm': (0.29581768513626894, 35),
#  'johnsonsb': (0.29576867701474074, 39),
#  'gengamma': (0.29417694873256994, 39),
#  'fatiguelife': (0.29372081970181196, 39),
#  'invgauss': (0.2846320009046507, 39),
#  'genextreme': (0.2829066628853462, 39),
#  'invweibull': (0.2766956490527307, 39),
#  'pearson3': (0.27494719355345193, 39),
#  'beta': (0.26787079604048336, 39),
#  'mielke': (0.25949825324394166, 39),
#  'geninvgauss': (0.2503522323445762, 39),
#  'exponweib': (0.24975654521790933, 39),
#  'gamma': (0.2474728529105934, 38),
#  'erlang': (0.24746544190022726, 38),
#  'recipinvgauss': (0.21025340016791544, 44),
#  'powernorm': (0.20492092410917787, 39),
#  'chi': (0.2012183791652837, 39),
#  'gausshyper': (0.19166459769017574, 39),
#  'foldcauchy': (0.19012923785500327, 39),
#  't': (0.18718763979917485, 39),
#  'vonmises_line': (0.18579368426381448, 45),
#  'weibull_max': (0.17653886094642127, 39),
#  'weibull_min': (0.17497550894018532, 36),
#  'nakagami': (0.1697247255381682, 37),
#  'laplace_asymmetric': (0.16408405346908375, 33),
#  'rice': (0.16310774872715086, 39),
#  'gennorm': (0.16107503083982966, 36),
#  'skewcauchy': (0.15514111555867288, 39),
#  'dgamma': (0.15163241490628573, 35),
#  'loglaplace': (0.15010637826856796, 39),
#  'dweibull': (0.13596027008763886, 36),
#  'hypsecant': (0.12666801965224134, 30),
#  'ncx2': (0.11799978519420201, 42),
#  'f': (0.10653047119624545, 39),
#  'kstwobign': (0.10540351276351216, 34),
#  'ncf': (0.10515372588796972, 39),
#  'crystalball': (0.10512977334487252, 39),
#  'foldnorm': (0.10362770153596679, 39),
#  'tukeylambda': (0.09755565854723995, 39),
#  'loggamma': (0.09693895213849182, 39),
#  'moyal': (0.07290510509032808, 33),
#  'rdist': (0.055162372943549434, 39),
#  'gumbel_r': (0.052422623722115876, 1),
#  'maxwell': (0.05211770805404978, 31),
#  'chi2': (0.04799577080171648, 39),
#  'logistic': (0.04292557503544759, 2),
#  'cauchy': (0.038889580726334014, 30),
#  'laplace': (0.022981636617964086, 0),
#  'triang': (0.020274956350828207, 39),
#  'norm': (0.019827534291987376, 0),
#  'exponpow': (0.01749338858580259, 39),
#  'genexpon': (0.01607777769764013, 39),
#  'cosine': (0.01273887589442421, 32),
#  'gompertz': (0.007929942638319512, 39),
#  'anglit': (0.005761949922368758, 35),
#  'rayleigh': (0.005083054266425161, 10),
#  'semicircular': (0.0023554115378648936, 37),
#  'gumbel_l': (0.0005333898262011247, 2),
#  'truncnorm': (0.0004663932043154506, 39),
#  'argus': (0.00031202021536189817, 39),
#  'kappa4': (0.00024107476301263883, 46),
#  'genhalflogistic': (0.0001640251969879177, 39),
#  'kappa3': (8.675111705407409e-05, 39),
#  'truncweibull_min': (4.8569579765480804e-05, 39),
#  'wald': (3.242320909583293e-05, 36),
#  'halfgennorm': (2.145978521360756e-05, 39),
#  'bradford': (2.0767144935016133e-05, 39),
#  'gilbrat': (1.181331281570258e-05, 39),
#  'gibrat': (1.181331281570258e-05, 39),
#  'truncexpon': (1.1309988266624371e-05, 37),
#  'wrapcauchy': (7.390790211846969e-06, 39),
#  'powerlaw': (3.2609765613093976e-06, 16),
#  'ksone': (1.8035179614775754e-06, 39),
#  'uniform': (1.2011433194608098e-06, 0),
#  'genpareto': (1.0314766623622146e-06, 39),
#  'arcsine': (2.84793349253941e-07, 39),
#  'halfcauchy': (6.612140888431391e-08, 36),
#  'halfnorm': (1.877748041013544e-08, 33),
#  'truncpareto': (1.859135254041243e-08, 39),
#  'halflogistic': (1.285017697888698e-08, 39),
#  'trapezoid': (1.0378296397372586e-10, 39),
#  'trapz': (1.0378296397372586e-10, 39),
#  'pareto': (5.717841051486617e-11, 29),
#  'expon': (2.263315522023093e-11, 0),
#  'lomax': (8.015518314944799e-13, 39),
#  'levy': (1.6547065468962614e-20, 36),
#  'levy_l': (1.3988881361885458e-20, 36),
#  '_fit': (nan, 48),
#  'kstwo': (nan, 48),
#  'loguniform': (nan, 48),
#  'reciprocal': (nan, 48),
#  'rv_continuous': (nan, 48),
#  'rv_histogram': (nan, 48),
#  'levy_stable': (0.06139418223459245, 46),
#  'studentized_range': (nan, 48),
#  'vonmises': (0.0, 47)}
