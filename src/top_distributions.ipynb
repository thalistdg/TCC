# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import tqdm
from math import ceil

from fitter import Fitter
from scipy.stats import exponnorm, erlang, gennorm


days_range = (22,23) #1,32
months_range = (1,2) #1,3
hours_range = (0, 24)

# %%
def load_data(column):
    stream = []
    days = range(*days_range)
    months = range(*months_range)
    for month in months:
        month_2_digits = '{month:02}'.format(month=month)
        path = '../COVID19_Tweets_Dataset_2020/Summary_Sentiment/2020_' + month_2_digits + '/'

        for day in days:
            if month == 2 and day > 29:
                continue
            if month == 1 and day < 22:
                continue

            for hour in range(*hours_range):
                file_name = path + f'2020_{month_2_digits}_' + '{day:02}'.format(day=day) + '_{hour:02}'.format(hour=hour) + '_Summary_Sentiment.csv'
                stream.append(pd.read_csv(file_name)[column])

    return (pd.concat(stream, ignore_index=True), stream) if len(stream) > 0 else (stream, stream)

# %%
stream_ln, tweets_per_file = load_data('Logits_Negative')

# %%
def get_fitted_summary(data):
    f = Fitter(data)
    # f.distributions = f.distributions[:2]
    f.fit()
    return f.summary(method='ks_pvalue', plot=False, clf=False, Nbest=110)

def get_dist_ks_values():
    n_tweets = 0
    dist_ks_values = {}
    n_files = 0
    for tweets_hour in tqdm.tqdm(tweets_per_file):
        n_files += 1
        n_tweets += len(tweets_hour)
        table = get_fitted_summary(tweets_hour)
        for i, row in table.iterrows():
            if i in dist_ks_values:
                dist_ks_values[i].append(row['ks_pvalue'])
            else:
                dist_ks_values[i] = [row['ks_pvalue']]

        if n_files % 24 == 0:
            c_day = n_files//24
            pd.DataFrame(dist_ks_values).to_pickle('../results/top_distributions_2020_{month:02}_{day:02}.pkl'.format(month=ceil(c_day/31), day=c_day+days_range[0]-1))
            dist_ks_values = {}

    if len(dist_ks_values) > 0:
        pd.DataFrame(dist_ks_values).to_pickle('../results/top_distributions_2020_{}.pkl'.format(n_files/24))

    print(f'Processed {len(tweets_per_file)} files!')
    print(f'Processed {len(tweets_per_file)//24} days!')
    print(f'Processed {n_tweets} tweets!')

    # return pd.DataFrame(dist_ks_values)

# %%
get_dist_ks_values()
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]SKIPPED _fit distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  38%|███▊      | 42/110 [00:05<00:15,  4.32it/s]SKIPPED kstwo distribution (taking more than 30 seconds)
# SKIPPED loguniform distribution (taking more than 30 seconds)
# Fitting 110 distributions:  72%|███████▏  | 79/110 [00:15<00:13,  2.24it/s]SKIPPED reciprocal distribution (taking more than 30 seconds)
# SKIPPED rv_histogram distribution (taking more than 30 seconds)
# SKIPPED rv_continuous distribution (taking more than 30 seconds)SKIPPED levy_stable distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED vonmises distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [00:54<00:00,  2.01it/s]
#   4%|▍         | 1/24 [00:55<21:09, 55.21s/it]SKIPPED _fit distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
# SKIPPED kstwo distribution (taking more than 30 seconds)
#
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# Fitting 110 distributions:  55%|█████▌    | 61/110 [00:19<00:19,  2.53it/s]SKIPPED loguniform distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  73%|███████▎  | 80/110 [00:27<00:13,  2.23it/s]SKIPPED reciprocal distribution (taking more than 30 seconds)SKIPPED rv_continuous distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  74%|███████▎  | 81/110 [00:28<00:12,  2.40it/s]SKIPPED rv_histogram distribution (taking more than 30 seconds)SKIPPED kappa4 distribution (taking more than 30 seconds)
# SKIPPED levy_stable distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# Fitting 110 distributions: 100%|██████████| 110/110 [01:09<00:00,  1.59it/s]
#   8%|▊         | 2/24 [02:05<23:29, 64.09s/it]SKIPPED _fit distribution (taking more than 30 seconds)
#
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
# Fitting 110 distributions:  25%|██▌       | 28/110 [00:08<00:27,  2.96it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
# Fitting 110 distributions:  38%|███▊      | 42/110 [00:12<00:19,  3.44it/s]SKIPPED kstwo distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  57%|█████▋    | 63/110 [00:16<00:11,  4.26it/s]SKIPPED loguniform distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# Fitting 110 distributions:  67%|██████▋   | 74/110 [00:20<00:11,  3.20it/s]SKIPPED rv_continuous distribution (taking more than 30 seconds)
#
# SKIPPED rv_histogram distribution (taking more than 30 seconds)
# Fitting 110 distributions:  68%|██████▊   | 75/110 [00:20<00:11,  2.98it/s]SKIPPED reciprocal distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [00:52<00:00,  2.11it/s]
#  12%|█▎        | 3/24 [02:57<20:32, 58.69s/it]SKIPPED _fit distribution (taking more than 30 seconds)
#
# SKIPPED kstwo distribution (taking more than 30 seconds)
# SKIPPED loguniform distribution (taking more than 30 seconds)SKIPPED rv_continuous distribution (taking more than 30 seconds)
# SKIPPED rv_histogram distribution (taking more than 30 seconds)
#
# SKIPPED reciprocal distribution (taking more than 30 seconds)/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#
# Fitting 110 distributions:  95%|█████████▍| 104/110 [00:43<00:03,  1.72it/s]SKIPPED kappa4 distribution (taking more than 30 seconds)SKIPPED levy_stable distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
#
# Fitting 110 distributions: 100%|██████████| 110/110 [01:09<00:00,  1.58it/s]
#  17%|█▋        | 4/24 [04:07<21:02, 63.14s/it]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED _fit distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  34%|███▎      | 37/110 [00:18<00:36,  1.99it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
# Fitting 110 distributions:  38%|███▊      | 42/110 [00:21<00:38,  1.77it/s]SKIPPED kstwo distribution (taking more than 30 seconds)
# Fitting 110 distributions:  52%|█████▏    | 57/110 [00:29<00:25,  2.07it/s]SKIPPED loguniform distribution (taking more than 30 seconds)SKIPPED reciprocal distribution (taking more than 30 seconds)
#
# SKIPPED rv_continuous distribution (taking more than 30 seconds)
# Fitting 110 distributions:  68%|██████▊   | 75/110 [00:40<00:21,  1.63it/s]SKIPPED rv_histogram distribution (taking more than 30 seconds)SKIPPED kappa4 distribution (taking more than 30 seconds)
#
# SKIPPED levy_stable distribution (taking more than 30 seconds)/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
# SKIPPED vonmises_line distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [01:25<00:00,  1.28it/s]
#  21%|██        | 5/24 [05:34<22:41, 71.65s/it]SKIPPED _fit distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  23%|██▎       | 25/110 [00:16<01:04,  1.32it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
# SKIPPED kstwo distribution (taking more than 30 seconds)
# SKIPPED loguniform distribution (taking more than 30 seconds)
# SKIPPED rv_continuous distribution (taking more than 30 seconds)SKIPPED reciprocal distribution (taking more than 30 seconds)
#
# SKIPPED rv_histogram distribution (taking more than 30 seconds)SKIPPED kappa4 distribution (taking more than 30 seconds)
#
# SKIPPED levy_stable distribution (taking more than 30 seconds)SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
#
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,SKIPPED vonmises distribution (taking more than 30 seconds)
# SKIPPED vonmises_line distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [01:36<00:00,  1.14it/s]
#  25%|██▌       | 6/24 [07:12<24:10, 80.59s/it]SKIPPED _fit distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  33%|███▎      | 36/110 [00:26<00:48,  1.53it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,SKIPPED kstwo distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  54%|█████▎    | 59/110 [00:41<00:29,  1.71it/s]SKIPPED loguniform distribution (taking more than 30 seconds)
# Fitting 110 distributions:  68%|██████▊   | 75/110 [00:51<00:23,  1.47it/s]SKIPPED reciprocal distribution (taking more than 30 seconds)SKIPPED rv_continuous distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  69%|██████▉   | 76/110 [00:51<00:24,  1.38it/s]SKIPPED rv_histogram distribution (taking more than 30 seconds)SKIPPED kappa4 distribution (taking more than 30 seconds)
# SKIPPED levy_stable distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  90%|█████████ | 99/110 [01:12<00:09,  1.12it/s]SKIPPED ncx2 distribution (taking more than 30 seconds)
# SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
# SKIPPED vonmises_line distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [01:42<00:00,  1.07it/s]
#  29%|██▉       | 7/24 [08:56<25:01, 88.32s/it]SKIPPED _fit distribution (taking more than 30 seconds)
#
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#
# Fitting 110 distributions:  45%|████▌     | 50/110 [00:52<00:54,  1.09it/s]SKIPPED kstwo distribution (taking more than 30 seconds)
# SKIPPED loguniform distribution (taking more than 30 seconds)SKIPPED kappa4 distribution (taking more than 30 seconds)
#
# SKIPPED levy_stable distribution (taking more than 30 seconds)
# Fitting 110 distributions:  73%|███████▎  | 80/110 [01:29<00:45,  1.51s/it]SKIPPED rv_continuous distribution (taking more than 30 seconds)
#
# SKIPPED rv_histogram distribution (taking more than 30 seconds)
# Fitting 110 distributions:  74%|███████▎  | 81/110 [01:30<00:41,  1.42s/it]SKIPPED reciprocal distribution (taking more than 30 seconds)SKIPPED ncx2 distribution (taking more than 30 seconds)
# SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
# SKIPPED vonmises_line distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [02:22<00:00,  1.29s/it]
#  33%|███▎      | 8/24 [11:20<28:15, 105.96s/it]SKIPPED _fit distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  30%|███       | 33/110 [00:31<01:14,  1.03it/s]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:3485: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
# SKIPPED burr distribution (taking more than 30 seconds)
#
# SKIPPED kstwo distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED genexpon distribution (taking more than 30 seconds)SKIPPED loguniform distribution (taking more than 30 seconds)
# SKIPPED rv_continuous distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  68%|██████▊   | 75/110 [01:06<00:26,  1.31it/s]SKIPPED rv_histogram distribution (taking more than 30 seconds)
# Fitting 110 distributions:  69%|██████▉   | 76/110 [01:06<00:24,  1.41it/s]SKIPPED reciprocal distribution (taking more than 30 seconds)
# Fitting 110 distributions:  70%|███████   | 77/110 [01:07<00:24,  1.33it/s]SKIPPED kappa4 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  79%|███████▉  | 87/110 [01:15<00:19,  1.21it/s]SKIPPED levy_stable distribution (taking more than 30 seconds)
# Fitting 110 distributions:  85%|████████▌ | 94/110 [01:25<00:28,  1.81s/it]SKIPPED ncx2 distribution (taking more than 30 seconds)SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
# SKIPPED vonmises_line distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [01:59<00:00,  1.09s/it]
#  38%|███▊      | 9/24 [13:21<27:39, 110.64s/it]SKIPPED _fit distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED alpha distribution (taking more than 30 seconds)
#
# SKIPPED argus distribution (taking more than 30 seconds)
# Fitting 110 distributions:   3%|▎         | 3/110 [00:32<20:42, 11.62s/it]SKIPPED arcsine distribution (taking more than 30 seconds)
# SKIPPED beta distribution (taking more than 30 seconds)
# SKIPPED betaprime distribution (taking more than 30 seconds)SKIPPED bradford distribution (taking more than 30 seconds)
# SKIPPED burr distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#
# Fitting 110 distributions:  11%|█         | 12/110 [00:50<04:57,  3.04s/it]SKIPPED burr12 distribution (taking more than 30 seconds)
# SKIPPED chi distribution (taking more than 30 seconds)
# SKIPPED chi2 distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  13%|█▎        | 14/110 [01:03<08:20,  5.22s/it]SKIPPED crystalball distribution (taking more than 30 seconds)
#
# SKIPPED dgamma distribution (taking more than 30 seconds)
# Fitting 110 distributions:  14%|█▎        | 15/110 [01:04<06:12,  3.92s/it]SKIPPED dweibull distribution (taking more than 30 seconds)SKIPPED erlang distribution (taking more than 30 seconds)
# SKIPPED exponpow distribution (taking more than 30 seconds)
# SKIPPED exponweib distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  20%|██        | 22/110 [01:33<10:02,  6.85s/it]SKIPPED f distribution (taking more than 30 seconds)
# SKIPPED fatiguelife distribution (taking more than 30 seconds)
# Fitting 110 distributions:  21%|██        | 23/110 [01:33<07:14,  4.99s/it]SKIPPED fisk distribution (taking more than 30 seconds)
# SKIPPED foldcauchy distribution (taking more than 30 seconds)SKIPPED foldnorm distribution (taking more than 30 seconds)
# SKIPPED gamma distribution (taking more than 30 seconds)
# SKIPPED gausshyper distribution (taking more than 30 seconds)
# SKIPPED genexpon distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  27%|██▋       | 30/110 [02:03<09:14,  6.93s/it]SKIPPED genextreme distribution (taking more than 30 seconds)SKIPPED gengamma distribution (taking more than 30 seconds)
# SKIPPED genhalflogistic distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  28%|██▊       | 31/110 [02:04<06:44,  5.12s/it]SKIPPED genhyperbolic distribution (taking more than 30 seconds)SKIPPED geninvgauss distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  34%|███▎      | 37/110 [02:10<01:35,  1.31s/it]SKIPPED genlogistic distribution (taking more than 30 seconds)SKIPPED gennorm distribution (taking more than 30 seconds)
# SKIPPED genpareto distribution (taking more than 30 seconds)
# SKIPPED gibrat distribution (taking more than 30 seconds)
#
# SKIPPED gilbrat distribution (taking more than 30 seconds)
# SKIPPED gompertz distribution (taking more than 30 seconds)
# SKIPPED halfgennorm distribution (taking more than 30 seconds)SKIPPED halflogistic distribution (taking more than 30 seconds)
# SKIPPED invgamma distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  45%|████▍     | 49/110 [03:04<07:59,  7.86s/it]SKIPPED kstwo distribution (taking more than 30 seconds)
#
# SKIPPED invgauss distribution (taking more than 30 seconds)
# SKIPPED invweibull distribution (taking more than 30 seconds)SKIPPED johnsonsb distribution (taking more than 30 seconds)
#
# SKIPPED johnsonsu distribution (taking more than 30 seconds)
# Fitting 110 distributions:  48%|████▊     | 53/110 [03:07<02:20,  2.47s/it]SKIPPED kappa3 distribution (taking more than 30 seconds)
#
# SKIPPED kappa4 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  51%|█████     | 56/110 [03:10<01:20,  1.50s/it]SKIPPED ksone distribution (taking more than 30 seconds)
# SKIPPED loguniform distribution (taking more than 30 seconds)
# SKIPPED levy_stable distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  60%|██████    | 66/110 [03:38<02:34,  3.52s/it]SKIPPED loggamma distribution (taking more than 30 seconds)
# SKIPPED loglaplace distribution (taking more than 30 seconds)
# SKIPPED lognorm distribution (taking more than 30 seconds)
# SKIPPED mielke distribution (taking more than 30 seconds)
# SKIPPED nakagami distribution (taking more than 30 seconds)
# SKIPPED ncf distribution (taking more than 30 seconds)
#
# SKIPPED nct distribution (taking more than 30 seconds)SKIPPED ncx2 distribution (taking more than 30 seconds)
# SKIPPED norminvgauss distribution (taking more than 30 seconds)
#
# SKIPPED rv_continuous distribution (taking more than 30 seconds)SKIPPED reciprocal distribution (taking more than 30 seconds)
#
# SKIPPED rv_histogram distribution (taking more than 30 seconds)SKIPPED pearson3 distribution (taking more than 30 seconds)
# SKIPPED powerlognorm distribution (taking more than 30 seconds)
# SKIPPED rdist distribution (taking more than 30 seconds)
# SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# SKIPPED rice distribution (taking more than 30 seconds)
# SKIPPED skewcauchy distribution (taking more than 30 seconds)
# SKIPPED skewnorm distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED t distribution (taking more than 30 seconds)
# SKIPPED trapezoid distribution (taking more than 30 seconds)
# SKIPPED trapz distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  89%|████████▉ | 98/110 [05:09<00:36,  3.00s/it]SKIPPED triang distribution (taking more than 30 seconds)
# SKIPPED truncnorm distribution (taking more than 30 seconds)
# SKIPPED truncpareto distribution (taking more than 30 seconds)
# SKIPPED truncweibull_min distribution (taking more than 30 seconds)
# SKIPPED tukeylambda distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
# SKIPPED vonmises_line distribution (taking more than 30 seconds)
# SKIPPED weibull_max distribution (taking more than 30 seconds)
# SKIPPED wrapcauchy distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [05:51<00:00,  3.20s/it]
#  42%|████▏     | 10/24 [19:14<43:19, 185.65s/it]/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED _fit distribution (taking more than 30 seconds)
# SKIPPED alpha distribution (taking more than 30 seconds)
#
# SKIPPED arcsine distribution (taking more than 30 seconds)SKIPPED argus distribution (taking more than 30 seconds)
#
# SKIPPED beta distribution (taking more than 30 seconds)SKIPPED bradford distribution (taking more than 30 seconds)
# SKIPPED betaprime distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:   5%|▍         | 5/110 [00:35<08:59,  5.14s/it]SKIPPED burr distribution (taking more than 30 seconds)
# SKIPPED burr12 distribution (taking more than 30 seconds)
# SKIPPED chi distribution (taking more than 30 seconds)
#
# SKIPPED chi2 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  13%|█▎        | 14/110 [01:05<06:27,  4.04s/it]SKIPPED crystalball distribution (taking more than 30 seconds)SKIPPED dgamma distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  14%|█▎        | 15/110 [01:06<05:18,  3.35s/it]SKIPPED dweibull distribution (taking more than 30 seconds)SKIPPED erlang distribution (taking more than 30 seconds)
# SKIPPED exponpow distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED exponweib distribution (taking more than 30 seconds)
# SKIPPED f distribution (taking more than 30 seconds)
# SKIPPED fatiguelife distribution (taking more than 30 seconds)
# SKIPPED fisk distribution (taking more than 30 seconds)
# SKIPPED foldcauchy distribution (taking more than 30 seconds)
# SKIPPED foldnorm distribution (taking more than 30 seconds)
# SKIPPED gamma distribution (taking more than 30 seconds)
# SKIPPED gausshyper distribution (taking more than 30 seconds)
# SKIPPED genexpon distribution (taking more than 30 seconds)
# SKIPPED genextreme distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  28%|██▊       | 31/110 [02:06<05:49,  4.43s/it]SKIPPED gengamma distribution (taking more than 30 seconds)SKIPPED genhalflogistic distribution (taking more than 30 seconds)
# SKIPPED genhyperbolic distribution (taking more than 30 seconds)
#
# SKIPPED geninvgauss distribution (taking more than 30 seconds)
# Fitting 110 distributions:  34%|███▎      | 37/110 [02:13<01:44,  1.44s/it]SKIPPED genlogistic distribution (taking more than 30 seconds)SKIPPED gennorm distribution (taking more than 30 seconds)
# SKIPPED genpareto distribution (taking more than 30 seconds)
#
# SKIPPED gibrat distribution (taking more than 30 seconds)SKIPPED gilbrat distribution (taking more than 30 seconds)
#
# SKIPPED gompertz distribution (taking more than 30 seconds)
# Fitting 110 distributions:  40%|████      | 44/110 [02:42<02:53,  2.63s/it]SKIPPED halfgennorm distribution (taking more than 30 seconds)SKIPPED halflogistic distribution (taking more than 30 seconds)
# SKIPPED invgamma distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  45%|████▍     | 49/110 [03:07<07:10,  7.06s/it]SKIPPED invgauss distribution (taking more than 30 seconds)SKIPPED kstwo distribution (taking more than 30 seconds)
#
# SKIPPED invweibull distribution (taking more than 30 seconds)SKIPPED johnsonsb distribution (taking more than 30 seconds)
# SKIPPED johnsonsu distribution (taking more than 30 seconds)
#
# SKIPPED kappa3 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  50%|█████     | 55/110 [03:14<01:36,  1.75s/it]SKIPPED kappa4 distribution (taking more than 30 seconds)SKIPPED ksone distribution (taking more than 30 seconds)
# SKIPPED loguniform distribution (taking more than 30 seconds)
# SKIPPED levy_stable distribution (taking more than 30 seconds)
# SKIPPED loggamma distribution (taking more than 30 seconds)
# SKIPPED loglaplace distribution (taking more than 30 seconds)
# SKIPPED lognorm distribution (taking more than 30 seconds)
# SKIPPED lomax distribution (taking more than 30 seconds)
# SKIPPED mielke distribution (taking more than 30 seconds)
# SKIPPED nakagami distribution (taking more than 30 seconds)
# SKIPPED ncf distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  71%|███████   | 78/110 [04:16<01:34,  2.96s/it]SKIPPED nct distribution (taking more than 30 seconds)SKIPPED ncx2 distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  73%|███████▎  | 80/110 [04:18<01:00,  2.00s/it]SKIPPED reciprocal distribution (taking more than 30 seconds)
#
# SKIPPED rv_continuous distribution (taking more than 30 seconds)
# Fitting 110 distributions:  74%|███████▎  | 81/110 [04:19<00:49,  1.70s/it]SKIPPED rv_histogram distribution (taking more than 30 seconds)
#
# SKIPPED norminvgauss distribution (taking more than 30 seconds)SKIPPED pearson3 distribution (taking more than 30 seconds)
# SKIPPED powerlognorm distribution (taking more than 30 seconds)
# SKIPPED powernorm distribution (taking more than 30 seconds)
# SKIPPED rdist distribution (taking more than 30 seconds)
#
# SKIPPED recipinvgauss distribution (taking more than 30 seconds)SKIPPED rice distribution (taking more than 30 seconds)
# SKIPPED semicircular distribution (taking more than 30 seconds)
# SKIPPED skewcauchy distribution (taking more than 30 seconds)
# SKIPPED skewnorm distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED t distribution (taking more than 30 seconds)
# SKIPPED trapezoid distribution (taking more than 30 seconds)
#
# SKIPPED trapz distribution (taking more than 30 seconds)
# Fitting 110 distributions:  89%|████████▉ | 98/110 [05:19<00:42,  3.50s/it]SKIPPED triang distribution (taking more than 30 seconds)SKIPPED truncnorm distribution (taking more than 30 seconds)
# SKIPPED truncpareto distribution (taking more than 30 seconds)
# SKIPPED truncweibull_min distribution (taking more than 30 seconds)
# SKIPPED tukeylambda distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  95%|█████████▌| 105/110 [05:46<00:27,  5.46s/it]SKIPPED vonmises distribution (taking more than 30 seconds)
# SKIPPED vonmises_line distribution (taking more than 30 seconds)SKIPPED weibull_max distribution (taking more than 30 seconds)
# SKIPPED weibull_min distribution (taking more than 30 seconds)
# SKIPPED wrapcauchy distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [06:00<00:00,  3.28s/it]
#  46%|████▌     | 11/24 [25:17<51:58, 239.87s/it]SKIPPED _fit distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED betaprime distribution (taking more than 30 seconds)
# SKIPPED argus distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:   3%|▎         | 3/110 [00:32<19:45, 11.08s/it]SKIPPED alpha distribution (taking more than 30 seconds)
# SKIPPED beta distribution (taking more than 30 seconds)
# Fitting 110 distributions:   4%|▎         | 4/110 [00:33<12:14,  6.93s/it]SKIPPED burr distribution (taking more than 30 seconds)
# SKIPPED arcsine distribution (taking more than 30 seconds)SKIPPED bradford distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  10%|█         | 11/110 [00:54<09:09,  5.55s/it]SKIPPED burr12 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  15%|█▍        | 16/110 [01:02<04:01,  2.57s/it]SKIPPED chi distribution (taking more than 30 seconds)SKIPPED chi2 distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  15%|█▌        | 17/110 [01:03<03:21,  2.17s/it]SKIPPED crystalball distribution (taking more than 30 seconds)SKIPPED exponpow distribution (taking more than 30 seconds)
#
# SKIPPED exponweib distribution (taking more than 30 seconds)SKIPPED f distribution (taking more than 30 seconds)
# SKIPPED fatiguelife distribution (taking more than 30 seconds)
#
# SKIPPED fisk distribution (taking more than 30 seconds)SKIPPED foldcauchy distribution (taking more than 30 seconds)
#
# SKIPPED foldnorm distribution (taking more than 30 seconds)/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED gausshyper distribution (taking more than 30 seconds)
# SKIPPED genexpon distribution (taking more than 30 seconds)
# SKIPPED genextreme distribution (taking more than 30 seconds)
# SKIPPED gengamma distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  29%|██▉       | 32/110 [02:03<05:15,  4.05s/it]SKIPPED genhalflogistic distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  30%|███       | 33/110 [02:04<04:04,  3.17s/it]SKIPPED genhyperbolic distribution (taking more than 30 seconds)SKIPPED geninvgauss distribution (taking more than 30 seconds)
# SKIPPED genlogistic distribution (taking more than 30 seconds)
# SKIPPED genpareto distribution (taking more than 30 seconds)
# SKIPPED gibrat distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  38%|███▊      | 42/110 [02:32<04:14,  3.74s/it]SKIPPED gilbrat distribution (taking more than 30 seconds)
# SKIPPED gompertz distribution (taking more than 30 seconds)SKIPPED halfgennorm distribution (taking more than 30 seconds)
#
# SKIPPED halflogistic distribution (taking more than 30 seconds)SKIPPED invgamma distribution (taking more than 30 seconds)
#
# SKIPPED kstwo distribution (taking more than 30 seconds)SKIPPED invgauss distribution (taking more than 30 seconds)
#
# SKIPPED invweibull distribution (taking more than 30 seconds)SKIPPED johnsonsb distribution (taking more than 30 seconds)
# SKIPPED johnsonsu distribution (taking more than 30 seconds)
#
# SKIPPED kappa3 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  50%|█████     | 55/110 [03:08<02:02,  2.22s/it]SKIPPED kappa4 distribution (taking more than 30 seconds)SKIPPED ksone distribution (taking more than 30 seconds)
# SKIPPED loguniform distribution (taking more than 30 seconds)
# SKIPPED levy_stable distribution (taking more than 30 seconds)
# SKIPPED loggamma distribution (taking more than 30 seconds)
# SKIPPED loglaplace distribution (taking more than 30 seconds)
# SKIPPED lognorm distribution (taking more than 30 seconds)
#
# SKIPPED lomax distribution (taking more than 30 seconds)SKIPPED mielke distribution (taking more than 30 seconds)
# SKIPPED ncf distribution (taking more than 30 seconds)
#
# SKIPPED nakagami distribution (taking more than 30 seconds)
# Fitting 110 distributions:  71%|███████   | 78/110 [04:12<01:15,  2.35s/it]SKIPPED nct distribution (taking more than 30 seconds)SKIPPED ncx2 distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  73%|███████▎  | 80/110 [04:17<01:12,  2.42s/it]SKIPPED reciprocal distribution (taking more than 30 seconds)SKIPPED rv_continuous distribution (taking more than 30 seconds)
# SKIPPED rv_histogram distribution (taking more than 30 seconds)
# SKIPPED norminvgauss distribution (taking more than 30 seconds)
# SKIPPED pearson3 distribution (taking more than 30 seconds)
# SKIPPED powerlognorm distribution (taking more than 30 seconds)
# SKIPPED powernorm distribution (taking more than 30 seconds)
# SKIPPED rdist distribution (taking more than 30 seconds)
#
# SKIPPED recipinvgauss distribution (taking more than 30 seconds)SKIPPED rice distribution (taking more than 30 seconds)
# SKIPPED skewcauchy distribution (taking more than 30 seconds)
# SKIPPED skewnorm distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED t distribution (taking more than 30 seconds)
# SKIPPED trapezoid distribution (taking more than 30 seconds)
#
# SKIPPED trapz distribution (taking more than 30 seconds)SKIPPED triang distribution (taking more than 30 seconds)
# SKIPPED truncexpon distribution (taking more than 30 seconds)
# SKIPPED truncnorm distribution (taking more than 30 seconds)
# SKIPPED truncpareto distribution (taking more than 30 seconds)
# SKIPPED truncweibull_min distribution (taking more than 30 seconds)
# SKIPPED tukeylambda distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
# SKIPPED vonmises_line distribution (taking more than 30 seconds)
# SKIPPED wald distribution (taking more than 30 seconds)
# SKIPPED weibull_max distribution (taking more than 30 seconds)
# SKIPPED wrapcauchy distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [06:01<00:00,  3.29s/it]
#  50%|█████     | 12/24 [31:22<55:34, 277.85s/it]SKIPPED _fit distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#
# SKIPPED alpha distribution (taking more than 30 seconds)
# Fitting 110 distributions:   2%|▏         | 2/110 [00:33<33:32, 18.64s/it]SKIPPED arcsine distribution (taking more than 30 seconds)
#
# SKIPPED betaprime distribution (taking more than 30 seconds)
# SKIPPED argus distribution (taking more than 30 seconds)SKIPPED bradford distribution (taking more than 30 seconds)
# SKIPPED beta distribution (taking more than 30 seconds)
# SKIPPED burr distribution (taking more than 30 seconds)
# SKIPPED burr12 distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  13%|█▎        | 14/110 [01:03<05:16,  3.30s/it]SKIPPED chi distribution (taking more than 30 seconds)
# Fitting 110 distributions:  14%|█▎        | 15/110 [01:04<04:04,  2.57s/it]SKIPPED chi2 distribution (taking more than 30 seconds)
# SKIPPED crystalball distribution (taking more than 30 seconds)SKIPPED exponpow distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  19%|█▉        | 21/110 [01:32<08:48,  5.94s/it]SKIPPED exponweib distribution (taking more than 30 seconds)
# SKIPPED f distribution (taking more than 30 seconds)
# SKIPPED fatiguelife distribution (taking more than 30 seconds)
# Fitting 110 distributions:  21%|██        | 23/110 [01:35<05:07,  3.54s/it]SKIPPED fisk distribution (taking more than 30 seconds)
# SKIPPED foldcauchy distribution (taking more than 30 seconds)SKIPPED foldnorm distribution (taking more than 30 seconds)
# SKIPPED gamma distribution (taking more than 30 seconds)
# SKIPPED gausshyper distribution (taking more than 30 seconds)
# SKIPPED genexpon distribution (taking more than 30 seconds)
#
# SKIPPED genextreme distribution (taking more than 30 seconds)
# Fitting 110 distributions:  27%|██▋       | 30/110 [02:04<06:13,  4.67s/it]SKIPPED gengamma distribution (taking more than 30 seconds)/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#
# Fitting 110 distributions:  28%|██▊       | 31/110 [02:06<04:50,  3.68s/it]SKIPPED genhalflogistic distribution (taking more than 30 seconds)SKIPPED genhyperbolic distribution (taking more than 30 seconds)
# SKIPPED geninvgauss distribution (taking more than 30 seconds)
# SKIPPED genlogistic distribution (taking more than 30 seconds)
# SKIPPED genpareto distribution (taking more than 30 seconds)
# SKIPPED gibrat distribution (taking more than 30 seconds)
# SKIPPED gilbrat distribution (taking more than 30 seconds)
#
# SKIPPED gompertz distribution (taking more than 30 seconds)SKIPPED halfgennorm distribution (taking more than 30 seconds)
# SKIPPED halflogistic distribution (taking more than 30 seconds)
# SKIPPED invgamma distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  45%|████▍     | 49/110 [03:06<05:39,  5.57s/it]SKIPPED invgauss distribution (taking more than 30 seconds)
# SKIPPED kstwo distribution (taking more than 30 seconds)
# Fitting 110 distributions:  45%|████▌     | 50/110 [03:07<04:14,  4.25s/it]SKIPPED invweibull distribution (taking more than 30 seconds)
# SKIPPED johnsonsb distribution (taking more than 30 seconds)
# SKIPPED johnsonsu distribution (taking more than 30 seconds)
# SKIPPED kappa3 distribution (taking more than 30 seconds)
# SKIPPED kappa4 distribution (taking more than 30 seconds)
#
# SKIPPED ksone distribution (taking more than 30 seconds)SKIPPED loguniform distribution (taking more than 30 seconds)
# SKIPPED levy_l distribution (taking more than 30 seconds)
# SKIPPED levy_stable distribution (taking more than 30 seconds)
# SKIPPED loggamma distribution (taking more than 30 seconds)
# SKIPPED loglaplace distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  61%|██████    | 67/110 [03:55<02:53,  4.02s/it]SKIPPED lognorm distribution (taking more than 30 seconds)SKIPPED lomax distribution (taking more than 30 seconds)
# SKIPPED mielke distribution (taking more than 30 seconds)
# SKIPPED nakagami distribution (taking more than 30 seconds)
# SKIPPED ncf distribution (taking more than 30 seconds)
# SKIPPED nct distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  72%|███████▏  | 79/110 [04:25<01:17,  2.51s/it]SKIPPED ncx2 distribution (taking more than 30 seconds)SKIPPED norminvgauss distribution (taking more than 30 seconds)
# SKIPPED rv_continuous distribution (taking more than 30 seconds)
#
# SKIPPED rv_histogram distribution (taking more than 30 seconds)SKIPPED reciprocal distribution (taking more than 30 seconds)
# SKIPPED pearson3 distribution (taking more than 30 seconds)
# SKIPPED powerlognorm distribution (taking more than 30 seconds)
# SKIPPED powernorm distribution (taking more than 30 seconds)
# SKIPPED rdist distribution (taking more than 30 seconds)
# SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# SKIPPED rice distribution (taking more than 30 seconds)
# SKIPPED skewcauchy distribution (taking more than 30 seconds)
# SKIPPED skewnorm distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
# SKIPPED t distribution (taking more than 30 seconds)
# SKIPPED trapezoid distribution (taking more than 30 seconds)
# SKIPPED trapz distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  89%|████████▉ | 98/110 [05:26<00:38,  3.18s/it]SKIPPED triang distribution (taking more than 30 seconds)SKIPPED truncexpon distribution (taking more than 30 seconds)
# SKIPPED truncnorm distribution (taking more than 30 seconds)
# SKIPPED truncpareto distribution (taking more than 30 seconds)
# SKIPPED truncweibull_min distribution (taking more than 30 seconds)
# SKIPPED tukeylambda distribution (taking more than 30 seconds)
# SKIPPED vonmises distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  95%|█████████▌| 105/110 [05:55<00:26,  5.29s/it]SKIPPED vonmises_line distribution (taking more than 30 seconds)SKIPPED weibull_max distribution (taking more than 30 seconds)
# SKIPPED weibull_min distribution (taking more than 30 seconds)
# SKIPPED wrapcauchy distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [06:09<00:00,  3.36s/it]
#  54%|█████▍    | 13/24 [37:35<56:14, 306.74s/it]SKIPPED _fit distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED alpha distribution (taking more than 30 seconds)
# SKIPPED anglit distribution (taking more than 30 seconds)
# SKIPPED arcsine distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:   2%|▏         | 2/110 [00:34<34:30, 19.17s/it]SKIPPED burr distribution (taking more than 30 seconds)
# SKIPPED betaprime distribution (taking more than 30 seconds)
#
# SKIPPED beta distribution (taking more than 30 seconds)
# SKIPPED argus distribution (taking more than 30 seconds)
# Fitting 110 distributions:   3%|▎         | 3/110 [00:35<19:52, 11.15s/it]SKIPPED bradford distribution (taking more than 30 seconds)
# SKIPPED burr12 distribution (taking more than 30 seconds)
#
# SKIPPED chi distribution (taking more than 30 seconds)
# SKIPPED chi2 distribution (taking more than 30 seconds)SKIPPED crystalball distribution (taking more than 30 seconds)
# SKIPPED dgamma distribution (taking more than 30 seconds)
#
# SKIPPED dweibull distribution (taking more than 30 seconds)SKIPPED erlang distribution (taking more than 30 seconds)
# SKIPPED exponnorm distribution (taking more than 30 seconds)
# SKIPPED exponpow distribution (taking more than 30 seconds)
# SKIPPED exponweib distribution (taking more than 30 seconds)
#
# SKIPPED f distribution (taking more than 30 seconds)
# SKIPPED fatiguelife distribution (taking more than 30 seconds)
# SKIPPED fisk distribution (taking more than 30 seconds)
# ...
#
# Fitting 110 distributions:  19%|█▉        | 21/110 [01:43<06:29,  4.38s/it]SKIPPED fatiguelife distribution (taking more than 30 seconds)SKIPPED fisk distribution (taking more than 30 seconds)
#
# SKIPPED foldcauchy distribution (taking more than 30 seconds)SKIPPED foldnorm distribution (taking more than 30 seconds)
# SKIPPED gamma distribution (taking more than 30 seconds)
# SKIPPED gausshyper distribution (taking more than 30 seconds)
#
# SKIPPED genexpon distribution (taking more than 30 seconds)SKIPPED genextreme distribution (taking more than 30 seconds)
#
# SKIPPED gengamma distribution (taking more than 30 seconds)
# Fitting 110 distributions:  26%|██▋       | 29/110 [02:17<06:59,  5.18s/it]SKIPPED genhalflogistic distribution (taking more than 30 seconds)SKIPPED genhyperbolic distribution (taking more than 30 seconds)
# SKIPPED geninvgauss distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  34%|███▎      | 37/110 [02:41<04:15,  3.50s/it]SKIPPED genlogistic distribution (taking more than 30 seconds)
# SKIPPED gennorm distribution (taking more than 30 seconds)
# Fitting 110 distributions:  35%|███▌      | 39/110 [02:45<03:17,  2.78s/it]SKIPPED genpareto distribution (taking more than 30 seconds)SKIPPED gibrat distribution (taking more than 30 seconds)
#
# SKIPPED gilbrat distribution (taking more than 30 seconds)
# Fitting 110 distributions:  36%|███▋      | 40/110 [02:48<03:09,  2.71s/it]SKIPPED gompertz distribution (taking more than 30 seconds)SKIPPED halfcauchy distribution (taking more than 30 seconds)
#
# SKIPPED halfgennorm distribution (taking more than 30 seconds)
# SKIPPED halflogistic distribution (taking more than 30 seconds)
# Fitting 110 distributions:  41%|████      | 45/110 [03:13<05:40,  5.24s/it]SKIPPED halfnorm distribution (taking more than 30 seconds)
# SKIPPED hypsecant distribution (taking more than 30 seconds)SKIPPED invgamma distribution (taking more than 30 seconds)
#
# SKIPPED invgauss distribution (taking more than 30 seconds)SKIPPED invweibull distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  44%|████▎     | 48/110 [03:22<03:38,  3.53s/it]SKIPPED kstwo distribution (taking more than 30 seconds)SKIPPED johnsonsb distribution (taking more than 30 seconds)
# SKIPPED johnsonsu distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  49%|████▉     | 54/110 [03:42<03:57,  4.23s/it]SKIPPED kappa3 distribution (taking more than 30 seconds)SKIPPED kappa4 distribution (taking more than 30 seconds)
# SKIPPED ksone distribution (taking more than 30 seconds)
# SKIPPED kstwobign distribution (taking more than 30 seconds)
#
# SKIPPED laplace_asymmetric distribution (taking more than 30 seconds)
# Fitting 110 distributions:  54%|█████▎    | 59/110 [03:55<02:14,  2.64s/it]SKIPPED levy distribution (taking more than 30 seconds)SKIPPED loguniform distribution (taking more than 30 seconds)
# SKIPPED levy_l distribution (taking more than 30 seconds)
# SKIPPED levy_stable distribution (taking more than 30 seconds)
#
# SKIPPED loggamma distribution (taking more than 30 seconds)
# SKIPPED loglaplace distribution (taking more than 30 seconds)
# SKIPPED lognorm distribution (taking more than 30 seconds)SKIPPED lomax distribution (taking more than 30 seconds)
#
# SKIPPED maxwell distribution (taking more than 30 seconds)SKIPPED mielke distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED moyal distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  66%|██████▋   | 73/110 [04:46<02:47,  4.52s/it]SKIPPED nakagami distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  67%|██████▋   | 74/110 [04:47<02:20,  3.91s/it]SKIPPED ncf distribution (taking more than 30 seconds)SKIPPED nct distribution (taking more than 30 seconds)
# SKIPPED ncx2 distribution (taking more than 30 seconds)
#
# SKIPPED norminvgauss distribution (taking more than 30 seconds)
# SKIPPED pareto distribution (taking more than 30 seconds)SKIPPED rv_continuous distribution (taking more than 30 seconds)
#
# SKIPPED rv_histogram distribution (taking more than 30 seconds)
# SKIPPED reciprocal distribution (taking more than 30 seconds)
# Fitting 110 distributions:  73%|███████▎  | 80/110 [05:07<01:39,  3.30s/it]SKIPPED pearson3 distribution (taking more than 30 seconds)
# SKIPPED powerlognorm distribution (taking more than 30 seconds)
# Fitting 110 distributions:  77%|███████▋  | 85/110 [05:18<01:01,  2.46s/it]SKIPPED powernorm distribution (taking more than 30 seconds)
# Fitting 110 distributions:  79%|███████▉  | 87/110 [05:25<01:10,  3.07s/it]SKIPPED rdist distribution (taking more than 30 seconds)SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# SKIPPED rice distribution (taking more than 30 seconds)
# SKIPPED semicircular distribution (taking more than 30 seconds)
#
# SKIPPED skewcauchy distribution (taking more than 30 seconds)
# Fitting 110 distributions:  83%|████████▎ | 91/110 [05:38<01:02,  3.30s/it]SKIPPED skewnorm distribution (taking more than 30 seconds)SKIPPED studentized_range distribution (taking more than 30 seconds)
#
# SKIPPED t distribution (taking more than 30 seconds)SKIPPED trapezoid distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  87%|████████▋ | 96/110 [06:00<01:01,  4.37s/it]SKIPPED trapz distribution (taking more than 30 seconds)
# Fitting 110 distributions:  88%|████████▊ | 97/110 [06:03<00:55,  4.25s/it]SKIPPED triang distribution (taking more than 30 seconds)
# Fitting 110 distributions:  89%|████████▉ | 98/110 [06:07<00:50,  4.25s/it]SKIPPED truncexpon distribution (taking more than 30 seconds)
# Fitting 110 distributions:  90%|█████████ | 99/110 [06:08<00:38,  3.48s/it]SKIPPED truncnorm distribution (taking more than 30 seconds)SKIPPED truncpareto distribution (taking more than 30 seconds)
# SKIPPED truncweibull_min distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  94%|█████████▎| 103/110 [06:20<00:24,  3.46s/it]SKIPPED tukeylambda distribution (taking more than 30 seconds)SKIPPED vonmises_line distribution (taking more than 30 seconds)
#
# SKIPPED vonmises distribution (taking more than 30 seconds)
# Fitting 110 distributions:  96%|█████████▋| 106/110 [06:35<00:17,  4.32s/it]SKIPPED wald distribution (taking more than 30 seconds)
# SKIPPED weibull_max distribution (taking more than 30 seconds)SKIPPED weibull_min distribution (taking more than 30 seconds)
#
# Fitting 110 distributions: 100%|██████████| 110/110 [06:46<00:00,  3.69s/it]SKIPPED wrapcauchy distribution (taking more than 30 seconds)
#  96%|█████████▌| 23/24 [1:43:57<06:45, 405.45s/it]SKIPPED _fit distribution (taking more than 30 seconds)
# SKIPPED anglit distribution (taking more than 30 seconds)
#
# SKIPPED alpha distribution (taking more than 30 seconds)
# Fitting 110 distributions:   2%|▏         | 2/110 [00:39<38:30, 21.39s/it]SKIPPED argus distribution (taking more than 30 seconds)
# SKIPPED beta distribution (taking more than 30 seconds)
# SKIPPED betaprime distribution (taking more than 30 seconds)
# SKIPPED bradford distribution (taking more than 30 seconds)
# Fitting 110 distributions:   3%|▎         | 3/110 [00:41<23:02, 12.92s/it]SKIPPED burr distribution (taking more than 30 seconds)
# SKIPPED arcsine distribution (taking more than 30 seconds)
# SKIPPED burr12 distribution (taking more than 30 seconds)
#
# SKIPPED cauchy distribution (taking more than 30 seconds)SKIPPED chi distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  10%|█         | 11/110 [01:12<08:48,  5.33s/it]SKIPPED chi2 distribution (taking more than 30 seconds)
# SKIPPED cosine distribution (taking more than 30 seconds)
#
# SKIPPED crystalball distribution (taking more than 30 seconds)
# Fitting 110 distributions:  11%|█         | 12/110 [01:16<08:03,  4.93s/it]SKIPPED dgamma distribution (taking more than 30 seconds)SKIPPED dweibull distribution (taking more than 30 seconds)
# SKIPPED erlang distribution (taking more than 30 seconds)
# SKIPPED exponnorm distribution (taking more than 30 seconds)
# SKIPPED exponpow distribution (taking more than 30 seconds)
#
# SKIPPED exponweib distribution (taking more than 30 seconds)/home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# SKIPPED f distribution (taking more than 30 seconds)
#
# SKIPPED fatiguelife distribution (taking more than 30 seconds)
# SKIPPED fisk distribution (taking more than 30 seconds)
# Fitting 110 distributions:  21%|██        | 23/110 [01:50<03:50,  2.65s/it]SKIPPED foldcauchy distribution (taking more than 30 seconds)SKIPPED foldnorm distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  25%|██▍       | 27/110 [02:13<08:54,  6.44s/it]SKIPPED gamma distribution (taking more than 30 seconds)
# SKIPPED gausshyper distribution (taking more than 30 seconds)
# SKIPPED genexpon distribution (taking more than 30 seconds)
# Fitting 110 distributions:  26%|██▋       | 29/110 [02:18<06:01,  4.47s/it]SKIPPED genextreme distribution (taking more than 30 seconds)SKIPPED gengamma distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  27%|██▋       | 30/110 [02:21<05:23,  4.05s/it]SKIPPED genhalflogistic distribution (taking more than 30 seconds)SKIPPED genhyperbolic distribution (taking more than 30 seconds)
# SKIPPED geninvgauss distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  33%|███▎      | 36/110 [02:44<06:12,  5.03s/it]SKIPPED genlogistic distribution (taking more than 30 seconds)SKIPPED gennorm distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  35%|███▍      | 38/110 [02:48<04:14,  3.53s/it]SKIPPED genpareto distribution (taking more than 30 seconds)
# SKIPPED gibrat distribution (taking more than 30 seconds)SKIPPED gilbrat distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  36%|███▋      | 40/110 [02:53<03:34,  3.07s/it]SKIPPED gompertz distribution (taking more than 30 seconds)SKIPPED halfcauchy distribution (taking more than 30 seconds)
#
# SKIPPED halfgennorm distribution (taking more than 30 seconds)
# SKIPPED halflogistic distribution (taking more than 30 seconds)
# Fitting 110 distributions:  41%|████      | 45/110 [03:17<04:57,  4.58s/it]SKIPPED halfnorm distribution (taking more than 30 seconds)SKIPPED hypsecant distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  42%|████▏     | 46/110 [03:21<04:55,  4.61s/it]SKIPPED invgamma distribution (taking more than 30 seconds)
# Fitting 110 distributions:  43%|████▎     | 47/110 [03:23<03:53,  3.70s/it]SKIPPED kstwo distribution (taking more than 30 seconds)
# SKIPPED invgauss distribution (taking more than 30 seconds)SKIPPED invweibull distribution (taking more than 30 seconds)
# SKIPPED johnsonsb distribution (taking more than 30 seconds)
# SKIPPED johnsonsu distribution (taking more than 30 seconds)
# SKIPPED kappa3 distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  50%|█████     | 55/110 [03:48<03:28,  3.79s/it]SKIPPED kappa4 distribution (taking more than 30 seconds)
# Fitting 110 distributions:  52%|█████▏    | 57/110 [03:51<02:28,  2.80s/it]SKIPPED ksone distribution (taking more than 30 seconds)SKIPPED kstwobign distribution (taking more than 30 seconds)
#
# SKIPPED laplace_asymmetric distribution (taking more than 30 seconds)SKIPPED levy distribution (taking more than 30 seconds)
# SKIPPED loguniform distribution (taking more than 30 seconds)
# SKIPPED levy_l distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  58%|█████▊    | 64/110 [04:16<03:41,  4.81s/it]SKIPPED levy_stable distribution (taking more than 30 seconds)SKIPPED loggamma distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  59%|█████▉    | 65/110 [04:21<03:25,  4.56s/it]SKIPPED loglaplace distribution (taking more than 30 seconds)
# Fitting 110 distributions:  60%|██████    | 66/110 [04:24<02:49,  3.86s/it]SKIPPED lognorm distribution (taking more than 30 seconds)
# SKIPPED lomax distribution (taking more than 30 seconds)
#
# SKIPPED maxwell distribution (taking more than 30 seconds)SKIPPED mielke distribution (taking more than 30 seconds)
# SKIPPED moyal distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  66%|██████▋   | 73/110 [04:48<02:51,  4.63s/it]SKIPPED nakagami distribution (taking more than 30 seconds)SKIPPED ncf distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  67%|██████▋   | 74/110 [04:52<02:37,  4.39s/it]SKIPPED nct distribution (taking more than 30 seconds)
# SKIPPED ncx2 distribution (taking more than 30 seconds)SKIPPED norminvgauss distribution (taking more than 30 seconds)
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#
# Fitting 110 distributions:  72%|███████▏  | 79/110 [05:06<01:37,  3.16s/it]SKIPPED pareto distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  73%|███████▎  | 80/110 [05:08<01:21,  2.72s/it]SKIPPED rv_continuous distribution (taking more than 30 seconds)SKIPPED rv_histogram distribution (taking more than 30 seconds)
# SKIPPED pearson3 distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  75%|███████▍  | 82/110 [05:12<01:10,  2.52s/it]SKIPPED reciprocal distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  77%|███████▋  | 85/110 [05:21<01:13,  2.96s/it]SKIPPED powerlognorm distribution (taking more than 30 seconds)
# SKIPPED powernorm distribution (taking more than 30 seconds)SKIPPED rdist distribution (taking more than 30 seconds)
# SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# SKIPPED rice distribution (taking more than 30 seconds)
# SKIPPED semicircular distribution (taking more than 30 seconds)
#
# SKIPPED skewcauchy distribution (taking more than 30 seconds)SKIPPED skewnorm distribution (taking more than 30 seconds)
# SKIPPED studentized_range distribution (taking more than 30 seconds)
#
# SKIPPED t distribution (taking more than 30 seconds)SKIPPED trapezoid distribution (taking more than 30 seconds)
# SKIPPED trapz distribution (taking more than 30 seconds)
# SKIPPED triang distribution (taking more than 30 seconds)
# SKIPPED truncexpon distribution (taking more than 30 seconds)
#
# SKIPPED truncnorm distribution (taking more than 30 seconds)SKIPPED truncpareto distribution (taking more than 30 seconds)
# SKIPPED truncweibull_min distribution (taking more than 30 seconds)
#
# Fitting 110 distributions:  94%|█████████▎| 103/110 [06:24<00:28,  4.04s/it]SKIPPED tukeylambda distribution (taking more than 30 seconds)SKIPPED vonmises distribution (taking more than 30 seconds)
#
# SKIPPED vonmises_line distribution (taking more than 30 seconds)
# Fitting 110 distributions:  96%|█████████▋| 106/110 [06:38<00:17,  4.33s/it]SKIPPED wald distribution (taking more than 30 seconds)
# SKIPPED weibull_max distribution (taking more than 30 seconds)
#
# SKIPPED weibull_min distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [06:55<00:00,  3.77s/it]
# 100%|██████████| 24/24 [1:51:05<00:00, 277.72s/it]
# Processed 24 files!
# Processed 1 days!
# Processed 36333 tweets!

# %%
pkls = []
for p in range(22,25):
    read_file = f'../results/top_distributions_2020_01_{p}.pkl'
    pkls.append(pd.read_pickle(read_file))
df_ks_values = pd.concat(pkls, ignore_index=True)

mean_pvalues = {}
for dist in df_ks_values:
    mean_pvalues[dist] = (np.nanmean(df_ks_values[dist]), df_ks_values[dist].isna().sum(), df_ks_values[dist][df_ks_values[dist] >= 0.01].count())

result = pd.DataFrame(mean_pvalues.values(), index=mean_pvalues.keys(), columns=['p_value', 'nan_count', 'greater_equal_.01'])

result.sort_values(inplace=True, by=['greater_equal_.01', 'nan_count', 'p_value'], ascending=[False, True, False])

result.head(20)
# Out:
#                      p_value  nan_count  greater_equal_.01
# gumbel_r            0.034702          1                  9
# laplace_asymmetric  0.144780         55                  9
# exponnorm           0.240352         56                  9
# dgamma              0.131415         57                  9
# dweibull            0.116537         58                  9
# erlang              0.208469         60                  9
# invweibull          0.249026         62                  9
# johnsonsu           0.418445         63                  9
# norminvgauss        0.417689         63                  9
# nct                 0.370731         63                  9
# logistic            0.028208          2                  8
# hypsecant           0.095001         48                  8
# moyal               0.057557         53                  8
# weibull_min         0.148751         58                  8
# gennorm             0.138064         58                  8
# genlogistic         0.321575         61                  8
# gamma               0.224975         61                  8
# powernorm           0.167663         61                  8
# fisk                0.357408         62                  8
# burr12              0.351444         62                  8

# %%
result = pd.DataFrame(mean_pvalues.values(), index=mean_pvalues.keys(), columns=['p_value', 'nan_count', 'greater_equal_.01'])

result['metrics_mean'] = (((len(df_ks_values) - result['nan_count']) + result['greater_equal_.01'])/len(df_ks_values) + result['p_value'])/3

result.sort_values(inplace=True, by=['metrics_mean'], ascending=[False])

result.head(20)
# Out:
#                     p_value  nan_count  greater_equal_.01  metrics_mean
# gumbel_r       3.470230e-02          1                  9      0.381938
# laplace        1.532109e-02          0                  7      0.370848
# logistic       2.820824e-02          2                  8      0.370514
# norm           1.321836e-02          0                  7      0.370147
# uniform        8.007622e-07          0                  0      0.333334
# expon          1.508877e-11          0                  0      0.333333
# gumbel_l       3.505133e-04          2                  0      0.324191
# rayleigh       3.273832e-03         13                  2      0.283499
# johnsonsu      4.184450e-01         63                  9      0.222815
# norminvgauss   4.176886e-01         63                  9      0.222563
# powerlaw       2.318917e-06         27                  0      0.208334
# nct            3.707307e-01         63                  9      0.206910
# fisk           3.574080e-01         62                  8      0.202469
# genhyperbolic  3.988886e-01         63                  6      0.202407
# burr12         3.514436e-01         62                  8      0.200481
# exponnorm      2.403519e-01         56                  9      0.195858
# genlogistic    3.215745e-01         61                  8      0.195154
# burr           3.435993e-01         63                  7      0.188607
# powerlognorm   3.061996e-01         63                  8      0.180770
# hypsecant      9.500101e-02         48                  8      0.179815
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /home/thalis/repositories/TCC/venv/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
